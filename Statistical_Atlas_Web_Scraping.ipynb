# %%
import bs4
import requests
from bs4 import BeautifulSoup

# %%
def get_url_list():
    root = "https://statisticalatlas.com"
    first_page = root + "/state/Pennsylvania/Overview"
    html = requests.get(first_page)
    soup = BeautifulSoup(html.content,'html.parser')
    counties = soup.select("div.info-table-contents-div a")
    url_list = []
    for county in counties:
        url = county['href']
        url = url.replace("/Overview","/Educational-Attainment")
        if(url.startswith("/county")):
            url = root+url
            url_list.append(url)
    url_list = list(set(url_list))
    return(url_list)

# %%
def get_soup(url):
    html = requests.get(url)
    soup = BeautifulSoup(html.content,'html.parser')
    results = soup.select("div.figure-container svg g g title")
    return(results)

# %%
def get_each_Educational_Attainment(results):
    result = []
    i = 0
    for r in results:
        if i < 3 and "%" in r.text.strip():
            result.append(r.text.strip())
            i = i + 1
    map = {"Higher Degree": result[0],"H.S. Diploma": result[1],"No H.S. Diploma": result[2]}
    return(map)

# %%
def get_all_Enductional_Attainment(url_list):
    for a_list in url_list:
        county_name = a_list.split("/")[5]
        print(county_name + ":")
        print(get_each_Educational_Attainment(get_soup(a_list)))
        print("\n")

# %%
get_all_Enductional_Attainment(get_url_list())
# Out:
# Columbia-County:
# {'Higher Degree': '28.952725%', 'H.S. Diploma': '60.021042%', 'No H.S. Diploma': '11.026233%'}
#
#
# Cumberland-County:
# {'Higher Degree': '41.619772%', 'H.S. Diploma': '49.751666%', 'No H.S. Diploma': '8.628561%'}
#
#
# Bucks-County:
# {'Higher Degree': '46.176217%', 'H.S. Diploma': '47.391071%', 'No H.S. Diploma': '6.432712%'}
#
#
# Delaware-County:
# {'Higher Degree': '44.301798%', 'H.S. Diploma': '48.100864%', 'No H.S. Diploma': '7.597338%'}
#
#
# Elk-County:
# {'Higher Degree': '29.261114%', 'H.S. Diploma': '62.282551%', 'No H.S. Diploma': '8.456335%'}
#
#
# Venango-County:
# {'Higher Degree': '24.638657%', 'H.S. Diploma': '64.267212%', 'No H.S. Diploma': '11.094130%'}
#
#
# Lycoming-County:
# {'Higher Degree': '30.987853%', 'H.S. Diploma': '57.870600%', 'No H.S. Diploma': '11.141547%'}
#
#
# Dauphin-County:
# {'Higher Degree': '37.827011%', 'H.S. Diploma': '51.251578%', 'No H.S. Diploma': '10.921411%'}
#
#
# Forest-County:
# {'Higher Degree': '12.363356%', 'H.S. Diploma': '68.421863%', 'No H.S. Diploma': '19.214781%'}
#
#
# Warren-County:
# {'Higher Degree': '28.182187%', 'H.S. Diploma': '63.029239%', 'No H.S. Diploma': '8.788575%'}
#
#
# Allegheny-County:
# {'Higher Degree': '48.553620%', 'H.S. Diploma': '45.314107%', 'No H.S. Diploma': '6.132273%'}
#
#
# Perry-County:
# {'Higher Degree': '25.011713%', 'H.S. Diploma': '63.253896%', 'No H.S. Diploma': '11.734391%'}
#
#
# Somerset-County:
# {'Higher Degree': '23.665175%', 'H.S. Diploma': '63.477354%', 'No H.S. Diploma': '12.857471%'}
#
#
# Clearfield-County:
# {'Higher Degree': '22.594565%', 'H.S. Diploma': '64.518576%', 'No H.S. Diploma': '12.886859%'}
#
#
# York-County:
# {'Higher Degree': '31.441754%', 'H.S. Diploma': '57.094820%', 'No H.S. Diploma': '11.463427%'}
#
#
# Snyder-County:
# {'Higher Degree': '24.907929%', 'H.S. Diploma': '57.981962%', 'No H.S. Diploma': '17.110109%'}
#
#
# Franklin-County:
# {'Higher Degree': '28.001552%', 'H.S. Diploma': '58.543624%', 'No H.S. Diploma': '13.454824%'}
#
#
# Bedford-County:
# {'Higher Degree': '21.324987%', 'H.S. Diploma': '65.331672%', 'No H.S. Diploma': '13.343341%'}
#
#
# Monroe-County:
# {'Higher Degree': '31.477949%', 'H.S. Diploma': '58.072379%', 'No H.S. Diploma': '10.449672%'}
#
#
# Cameron-County:
# {'Higher Degree': '25.027533%', 'H.S. Diploma': '62.142070%', 'No H.S. Diploma': '12.830396%'}
#
#
# Butler-County:
# {'Higher Degree': '42.915945%', 'H.S. Diploma': '50.596342%', 'No H.S. Diploma': '6.487713%'}
#
#
# Lackawanna-County:
# {'Higher Degree': '35.063097%', 'H.S. Diploma': '54.971623%', 'No H.S. Diploma': '9.965280%'}
#
#
# Potter-County:
# {'Higher Degree': '22.597403%', 'H.S. Diploma': '64.902597%', 'No H.S. Diploma': '12.500000%'}
#
#
# Huntingdon-County:
# {'Higher Degree': '21.867833%', 'H.S. Diploma': '66.738020%', 'No H.S. Diploma': '11.394147%'}
#
#
# Tioga-County:
# {'Higher Degree': '28.645460%', 'H.S. Diploma': '60.441171%', 'No H.S. Diploma': '10.913368%'}
#
#
# Wyoming-County:
# {'Higher Degree': '27.111246%', 'H.S. Diploma': '64.535120%', 'No H.S. Diploma': '8.353634%'}
#
#
# Schuylkill-County:
# {'Higher Degree': '24.926056%', 'H.S. Diploma': '62.960381%', 'No H.S. Diploma': '12.113562%'}
#
#
# Fayette-County:
# {'Higher Degree': '23.690041%', 'H.S. Diploma': '63.674039%', 'No H.S. Diploma': '12.635920%'}
#
#
# Northampton-County:
# {'Higher Degree': '36.945136%', 'H.S. Diploma': '53.478113%', 'No H.S. Diploma': '9.576751%'}
#
#
# Luzerne-County:
# {'Higher Degree': '31.579365%', 'H.S. Diploma': '57.514959%', 'No H.S. Diploma': '10.905676%'}
#
#
# Blair-County:
# {'Higher Degree': '27.754321%', 'H.S. Diploma': '62.919552%', 'No H.S. Diploma': '9.326127%'}
#
#
# Cambria-County:
# {'Higher Degree': '29.801918%', 'H.S. Diploma': '60.670589%', 'No H.S. Diploma': '9.527493%'}
#
#
# Fulton-County:
# {'Higher Degree': '20.017298%', 'H.S. Diploma': '66.961368%', 'No H.S. Diploma': '13.021334%'}
#
#
# Jefferson-County:
# {'Higher Degree': '24.602898%', 'H.S. Diploma': '64.477981%', 'No H.S. Diploma': '10.919121%'}
#
#
# Washington-County:
# {'Higher Degree': '37.475613%', 'H.S. Diploma': '54.278622%', 'No H.S. Diploma': '8.245765%'}
#
#
# Berks-County:
# {'Higher Degree': '31.591554%', 'H.S. Diploma': '53.940852%', 'No H.S. Diploma': '14.467594%'}
#
#
# Adams-County:
# {'Higher Degree': '30.017963%', 'H.S. Diploma': '57.774289%', 'No H.S. Diploma': '12.207748%'}
#
#
# Clinton-County:
# {'Higher Degree': '27.007387%', 'H.S. Diploma': '60.626872%', 'No H.S. Diploma': '12.365742%'}
#
#
# Northumberland-County:
# {'Higher Degree': '22.719044%', 'H.S. Diploma': '63.099951%', 'No H.S. Diploma': '14.181005%'}
#
#
# Erie-County:
# {'Higher Degree': '35.329083%', 'H.S. Diploma': '55.740909%', 'No H.S. Diploma': '8.930008%'}
#
#
# McKean-County:
# {'Higher Degree': '24.776030%', 'H.S. Diploma': '64.785321%', 'No H.S. Diploma': '10.438649%'}
#
#
# Sullivan-County:
# {'Higher Degree': '23.460053%', 'H.S. Diploma': '65.582435%', 'No H.S. Diploma': '10.957512%'}
#
#
# Lehigh-County:
# {'Higher Degree': '37.977429%', 'H.S. Diploma': '50.087933%', 'No H.S. Diploma': '11.934639%'}
#
#
# Indiana-County:
# {'Higher Degree': '30.553032%', 'H.S. Diploma': '58.400570%', 'No H.S. Diploma': '11.046398%'}
#
#
# Carbon-County:
# {'Higher Degree': '25.709742%', 'H.S. Diploma': '63.515319%', 'No H.S. Diploma': '10.774939%'}
#
#
# Beaver-County:
# {'Higher Degree': '35.025265%', 'H.S. Diploma': '56.907178%', 'No H.S. Diploma': '8.067558%'}
#
#
# Clarion-County:
# {'Higher Degree': '29.055477%', 'H.S. Diploma': '59.458632%', 'No H.S. Diploma': '11.485891%'}
#
#
# Pike-County:
# {'Higher Degree': '33.425244%', 'H.S. Diploma': '57.320466%', 'No H.S. Diploma': '9.254290%'}
#
#
# Mercer-County:
# {'Higher Degree': '29.757764%', 'H.S. Diploma': '59.755762%', 'No H.S. Diploma': '10.486474%'}
#
#
# Bradford-County:
# {'Higher Degree': '26.372392%', 'H.S. Diploma': '62.481082%', 'No H.S. Diploma': '11.146526%'}
#
#
# Lancaster-County:
# {'Higher Degree': '32.703155%', 'H.S. Diploma': '51.897731%', 'No H.S. Diploma': '15.399115%'}
#
#
# Union-County:
# {'Higher Degree': '29.292732%', 'H.S. Diploma': '55.875464%', 'No H.S. Diploma': '14.831804%'}
#
#
# Lawrence-County:
# {'Higher Degree': '29.150010%', 'H.S. Diploma': '60.357573%', 'No H.S. Diploma': '10.492417%'}
#
#
# Centre-County:
# {'Higher Degree': '50.010130%', 'H.S. Diploma': '43.290219%', 'No H.S. Diploma': '6.699651%'}
#
#
# Mifflin-County:
# {'Higher Degree': '18.579385%', 'H.S. Diploma': '64.472396%', 'No H.S. Diploma': '16.948219%'}
#
#
# Lebanon-County:
# {'Higher Degree': '26.886219%', 'H.S. Diploma': '59.145626%', 'No H.S. Diploma': '13.968156%'}
#
#
# Montgomery-County:
# {'Higher Degree': '54.288002%', 'H.S. Diploma': '39.614986%', 'No H.S. Diploma': '6.097012%'}
#
#
# Montour-County:
# {'Higher Degree': '35.094283%', 'H.S. Diploma': '54.751571%', 'No H.S. Diploma': '10.154145%'}
#
#
# Juniata-County:
# {'Higher Degree': '20.003449%', 'H.S. Diploma': '62.355579%', 'No H.S. Diploma': '17.640973%'}
#
#
# Crawford-County:
# {'Higher Degree': '28.110714%', 'H.S. Diploma': '60.210551%', 'No H.S. Diploma': '11.678735%'}
#
#
# Chester-County:
# {'Higher Degree': '56.377632%', 'H.S. Diploma': '36.576941%', 'No H.S. Diploma': '7.045428%'}
#
#
# Wayne-County:
# {'Higher Degree': '27.742471%', 'H.S. Diploma': '62.135872%', 'No H.S. Diploma': '10.121657%'}
#
#
# Philadelphia-County:
# {'Higher Degree': '31.854756%', 'H.S. Diploma': '50.754406%', 'No H.S. Diploma': '17.390838%'}
#
#
# Westmoreland-County:
# {'Higher Degree': '37.561537%', 'H.S. Diploma': '55.462249%', 'No H.S. Diploma': '6.976214%'}
#
#
# Susquehanna-County:
# {'Higher Degree': '25.327568%', 'H.S. Diploma': '63.567872%', 'No H.S. Diploma': '11.104560%'}
#
#
# Greene-County:
# {'Higher Degree': '24.200538%', 'H.S. Diploma': '62.522415%', 'No H.S. Diploma': '13.277047%'}
#
#
# Armstrong-County:
# {'Higher Degree': '24.748873%', 'H.S. Diploma': '64.351113%', 'No H.S. Diploma': '10.900014%'}

# %%
def get_each_Detailed_Educational_Attainment(results):
    result = []
    i = 0
    for r in results:
        if i < 12 and "%" in r.text.strip():
            i = i + 1
        elif i < 22 and "%" in r.text.strip():
            result.append(r.text.strip())
            i = i + 1
    map = {"Doctorate": result[0],"Professional": result[1],"Master's": result[2],
   "Bachelor's":result[3],"Associate's":result[4],"Some College":result[5],
   "High School": result[6],"Some H.S.":result[7],"Less than H.S.":result[8],
   "None":result[9]}
    return(map)

# %%
def get_all_Detailed_Educational_Attainment(url_list):
    for a_list in url_list:
        county_name = a_list.split("/")[5]
        print(county_name + ":")
        print(get_each_Detailed_Educational_Attainment(get_soup(a_list)))
        print("\n")

# %%
get_all_Detailed_Educational_Attainment(get_url_list())
# Out:
# Columbia-County:
# {'Doctorate': '1.239622%', 'Professional': '1.072662%', "Master's": '5.612607%', "Bachelor's": '13.434577%', "Associate's": '7.593258%', 'Some College': '15.406079%', 'High School': '44.614962%', 'Some H.S.': '8.167326%', 'Less than H.S.': '2.255106%', 'None': '0.603801%'}
#
#
# Cumberland-County:
# {'Doctorate': '1.315401%', 'Professional': '2.045066%', "Master's": '9.489766%', "Bachelor's": '20.792780%', "Associate's": '7.976759%', 'Some College': '15.860320%', 'High School': '33.891347%', 'Some H.S.': '6.058515%', 'Less than H.S.': '1.840972%', 'None': '0.729075%'}
#
#
# Bucks-County:
# {'Doctorate': '1.691117%', 'Professional': '2.189768%', "Master's": '11.276524%', "Bachelor's": '23.192136%', "Associate's": '7.826673%', 'Some College': '17.217369%', 'High School': '30.173702%', 'Some H.S.': '4.600480%', 'Less than H.S.': '1.236112%', 'None': '0.596120%'}
#
#
# Delaware-County:
# {'Doctorate': '2.054322%', 'Professional': '2.748621%', "Master's": '10.682789%', "Bachelor's": '21.297842%', "Associate's": '7.518224%', 'Some College': '16.522153%', 'High School': '31.578711%', 'Some H.S.': '5.162793%', 'Less than H.S.': '1.522749%', 'None': '0.911797%'}
#
#
# Elk-County:
# {'Doctorate': '0.364611%', 'Professional': '0.768758%', "Master's": '4.441223%', "Bachelor's": '12.199086%', "Associate's": '11.487436%', 'Some College': '13.499385%', 'High School': '48.783166%', 'Some H.S.': '6.049025%', 'Less than H.S.': '1.497979%', 'None': '0.909331%'}
#
#
# Venango-County:
# {'Doctorate': '0.256437%', 'Professional': '0.725276%', "Master's": '4.644356%', "Bachelor's": '10.884318%', "Associate's": '8.128270%', 'Some College': '15.000259%', 'High School': '49.266953%', 'Some H.S.': '7.628348%', 'Less than H.S.': '2.121432%', 'None': '1.344351%'}
#
#
# Lycoming-County:
# {'Doctorate': '0.658156%', 'Professional': '1.362172%', "Master's": '5.430094%', "Bachelor's": '13.174269%', "Associate's": '10.363163%', 'Some College': '17.657412%', 'High School': '40.213188%', 'Some H.S.': '8.648984%', 'Less than H.S.': '1.756321%', 'None': '0.736242%'}
#
#
# Dauphin-County:
# {'Doctorate': '1.253443%', 'Professional': '2.535118%', "Master's": '7.491890%', "Bachelor's": '18.044140%', "Associate's": '8.502421%', 'Some College': '17.257875%', 'High School': '33.993703%', 'Some H.S.': '7.473778%', 'Less than H.S.': '2.346010%', 'None': '1.101623%'}
#
#
# Forest-County:
# {'Doctorate': '0.477290%', 'Professional': '0.030793%', "Master's": '2.709777%', "Bachelor's": '5.080831%', "Associate's": '4.064665%', 'Some College': '13.779831%', 'High School': '54.642032%', 'Some H.S.': '15.242494%', 'Less than H.S.': '1.478060%', 'None': '2.494226%'}
#
#
# Warren-County:
# {'Doctorate': '0.543588%', 'Professional': '0.884597%', "Master's": '4.669458%', "Bachelor's": '12.330340%', "Associate's": '9.754204%', 'Some College': '16.432575%', 'High School': '46.596664%', 'Some H.S.': '6.360997%', 'Less than H.S.': '1.759065%', 'None': '0.668512%'}
#
#
# Allegheny-County:
# {'Doctorate': '2.178006%', 'Professional': '2.861175%', "Master's": '11.092264%', "Bachelor's": '22.938138%', "Associate's": '9.484039%', 'Some College': '16.391396%', 'High School': '28.922711%', 'Some H.S.': '4.308747%', 'Less than H.S.': '1.052191%', 'None': '0.771334%'}
#
#
# Perry-County:
# {'Doctorate': '0.293594%', 'Professional': '0.727738%', "Master's": '4.388294%', "Bachelor's": '10.934816%', "Associate's": '8.667271%', 'Some College': '17.022207%', 'High School': '46.231689%', 'Some H.S.': '8.682887%', 'Less than H.S.': '2.326889%', 'None': '0.724615%'}
#
#
# Somerset-County:
# {'Doctorate': '0.488124%', 'Professional': '0.944414%', "Master's": '3.871390%', "Bachelor's": '10.162177%', "Associate's": '8.199070%', 'Some College': '14.325381%', 'High School': '49.151973%', 'Some H.S.': '8.161930%', 'Less than H.S.': '3.464620%', 'None': '1.230922%'}
#
#
# Clearfield-County:
# {'Doctorate': '0.510755%', 'Professional': '0.517497%', "Master's": '3.042613%', "Bachelor's": '9.148068%', "Associate's": '9.375632%', 'Some College': '13.756658%', 'High School': '50.761918%', 'Some H.S.': '9.257636%', 'Less than H.S.': '2.358236%', 'None': '1.270986%'}
#
#
# York-County:
# {'Doctorate': '0.673180%', 'Professional': '1.318118%', "Master's": '6.049093%', "Bachelor's": '15.074953%', "Associate's": '8.326410%', 'Some College': '16.483376%', 'High School': '40.611444%', 'Some H.S.': '8.020688%', 'Less than H.S.': '2.601428%', 'None': '0.841310%'}
#
#
# Snyder-County:
# {'Doctorate': '0.935738%', 'Professional': '1.210071%', "Master's": '3.919579%', "Bachelor's": '10.612552%', "Associate's": '8.229989%', 'Some College': '12.499061%', 'High School': '45.482901%', 'Some H.S.': '10.150319%', 'Less than H.S.': '5.783540%', 'None': '1.176250%'}
#
#
# Franklin-County:
# {'Doctorate': '0.740867%', 'Professional': '0.999177%', "Master's": '5.917473%', "Bachelor's": '12.397930%', "Associate's": '7.946105%', 'Some College': '15.413438%', 'High School': '43.130186%', 'Some H.S.': '9.441085%', 'Less than H.S.': '3.278549%', 'None': '0.735190%'}
#
#
# Bedford-County:
# {'Doctorate': '0.529655%', 'Professional': '1.019657%', "Master's": '3.883193%', "Bachelor's": '8.330029%', "Associate's": '7.562454%', 'Some College': '14.532941%', 'High School': '50.798731%', 'Some H.S.': '9.587606%', 'Less than H.S.': '2.580298%', 'None': '1.175438%'}
#
#
# Monroe-County:
# {'Doctorate': '0.764761%', 'Professional': '0.987301%', "Master's": '6.765397%', "Bachelor's": '15.036472%', "Associate's": '7.924018%', 'Some College': '21.598757%', 'High School': '36.473622%', 'Some H.S.': '7.383564%', 'Less than H.S.': '2.119430%', 'None': '0.946679%'}
#
#
# Cameron-County:
# {'Doctorate': '0.495595%', 'Professional': '1.046256%', "Master's": '2.340308%', "Bachelor's": '11.701542%', "Associate's": '9.443833%', 'Some College': '16.272026%', 'High School': '45.870044%', 'Some H.S.': '9.994493%', 'Less than H.S.': '2.367841%', 'None': '0.468062%'}
#
#
# Butler-County:
# {'Doctorate': '1.174288%', 'Professional': '1.405773%', "Master's": '9.371311%', "Bachelor's": '21.338781%', "Associate's": '9.625791%', 'Some College': '16.417041%', 'High School': '34.179301%', 'Some H.S.': '4.714783%', 'Less than H.S.': '1.194217%', 'None': '0.578713%'}
#
#
# Lackawanna-County:
# {'Doctorate': '1.057622%', 'Professional': '1.442879%', "Master's": '7.149629%', "Bachelor's": '16.449222%', "Associate's": '8.963744%', 'Some College': '17.357281%', 'High School': '37.614342%', 'Some H.S.': '6.929292%', 'Less than H.S.': '1.965681%', 'None': '1.070308%'}
#
#
# Potter-County:
# {'Doctorate': '0.170455%', 'Professional': '0.876623%', "Master's": '5.324675%', "Bachelor's": '8.676948%', "Associate's": '7.548701%', 'Some College': '17.037338%', 'High School': '47.865260%', 'Some H.S.': '9.001623%', 'Less than H.S.': '2.426948%', 'None': '1.071429%'}
#
#
# Huntingdon-County:
# {'Doctorate': '0.837895%', 'Professional': '0.510688%', "Master's": '3.779701%', "Bachelor's": '9.583805%', "Associate's": '7.155744%', 'Some College': '15.577505%', 'High School': '51.160515%', 'Some H.S.': '8.418703%', 'Less than H.S.': '2.045809%', 'None': '0.929635%'}
#
#
# Tioga-County:
# {'Doctorate': '0.825066%', 'Professional': '1.005762%', "Master's": '6.136852%', "Bachelor's": '12.519178%', "Associate's": '8.158604%', 'Some College': '16.327435%', 'High School': '44.113736%', 'Some H.S.': '8.097235%', 'Less than H.S.': '2.045617%', 'None': '0.770516%'}
#
#
# Wyoming-County:
# {'Doctorate': '0.487211%', 'Professional': '0.832318%', "Master's": '5.298417%', "Bachelor's": '11.982339%', "Associate's": '8.510962%', 'Some College': '16.666667%', 'High School': '47.868453%', 'Some H.S.': '6.364190%', 'Less than H.S.': '1.679862%', 'None': '0.309582%'}
#
#
# Schuylkill-County:
# {'Doctorate': '0.443662%', 'Professional': '0.842109%', "Master's": '4.392344%', "Bachelor's": '9.638100%', "Associate's": '9.609842%', 'Some College': '15.281362%', 'High School': '47.679019%', 'Some H.S.': '9.141689%', 'Less than H.S.': '1.992238%', 'None': '0.979635%'}
#
#
# Fayette-County:
# {'Doctorate': '0.474950%', 'Professional': '0.634976%', "Master's": '3.620081%', "Bachelor's": '10.003693%', "Associate's": '8.956342%', 'Some College': '13.272947%', 'High School': '50.401091%', 'Some H.S.': '9.066103%', 'Less than H.S.': '2.601453%', 'None': '0.968364%'}
#
#
# Northampton-County:
# {'Doctorate': '1.282661%', 'Professional': '1.438193%', "Master's": '7.362817%', "Bachelor's": '17.790195%', "Associate's": '9.071271%', 'Some College': '18.339838%', 'High School': '35.138275%', 'Some H.S.': '6.367699%', 'Less than H.S.': '2.298420%', 'None': '0.910631%'}
#
#
# Luzerne-County:
# {'Doctorate': '0.858538%', 'Professional': '1.292877%', "Master's": '6.246555%', "Bachelor's": '13.654583%', "Associate's": '9.526812%', 'Some College': '18.355594%', 'High School': '39.159365%', 'Some H.S.': '7.636883%', 'Less than H.S.': '2.315450%', 'None': '0.953343%'}
#
#
# Blair-County:
# {'Doctorate': '0.647413%', 'Professional': '1.036987%', "Master's": '4.707538%', "Bachelor's": '13.141924%', "Associate's": '8.220458%', 'Some College': '14.789168%', 'High School': '48.130383%', 'Some H.S.': '7.114789%', 'Less than H.S.': '1.612340%', 'None': '0.598998%'}
#
#
# Cambria-County:
# {'Doctorate': '0.777671%', 'Professional': '1.475947%', "Master's": '5.359215%', "Bachelor's": '12.607642%', "Associate's": '9.581442%', 'Some College': '15.137110%', 'High School': '45.533479%', 'Some H.S.': '6.451416%', 'Less than H.S.': '2.108060%', 'None': '0.968018%'}
#
#
# Fulton-County:
# {'Doctorate': '0.345954%', 'Professional': '0.317125%', "Master's": '4.660773%', "Bachelor's": '8.053046%', "Associate's": '6.640400%', 'Some College': '14.578128%', 'High School': '52.383240%', 'Some H.S.': '9.494522%', 'Less than H.S.': '2.565827%', 'None': '0.960984%'}
#
#
# Jefferson-County:
# {'Doctorate': '0.377287%', 'Professional': '0.824324%', "Master's": '3.798231%', "Bachelor's": '9.828477%', "Associate's": '9.774579%', 'Some College': '13.195523%', 'High School': '51.282458%', 'Some H.S.': '6.898957%', 'Less than H.S.': '3.408262%', 'None': '0.611902%'}
#
#
# Washington-County:
# {'Doctorate': '0.888016%', 'Professional': '1.391225%', "Master's": '7.322094%', "Bachelor's": '18.535985%', "Associate's": '9.338294%', 'Some College': '15.437348%', 'High School': '38.841274%', 'Some H.S.': '5.720975%', 'Less than H.S.': '1.628702%', 'None': '0.896089%'}
#
#
# Berks-County:
# {'Doctorate': '0.701315%', 'Professional': '1.118148%', "Master's": '6.544170%', "Bachelor's": '15.254506%', "Associate's": '7.973415%', 'Some College': '15.872382%', 'High School': '38.068470%', 'Some H.S.': '8.894835%', 'Less than H.S.': '4.408575%', 'None': '1.164183%'}
#
#
# Adams-County:
# {'Doctorate': '1.016959%', 'Professional': '1.097580%', "Master's": '6.975856%', "Bachelor's": '12.776340%', "Associate's": '8.151228%', 'Some College': '15.909252%', 'High School': '41.865037%', 'Some H.S.': '7.898050%', 'Less than H.S.': '3.367703%', 'None': '0.941995%'}
#
#
# Clinton-County:
# {'Doctorate': '0.750649%', 'Professional': '0.722699%', "Master's": '4.819325%', "Bachelor's": '11.199840%', "Associate's": '9.514873%', 'Some College': '14.617688%', 'High School': '46.009183%', 'Some H.S.': '8.828109%', 'Less than H.S.': '2.627271%', 'None': '0.910361%'}
#
#
# Northumberland-County:
# {'Doctorate': '0.438603%', 'Professional': '0.822748%', "Master's": '4.207939%', "Bachelor's": '9.552125%', "Associate's": '7.697629%', 'Some College': '12.878442%', 'High School': '50.221509%', 'Some H.S.': '9.977481%', 'Less than H.S.': '3.270388%', 'None': '0.933135%'}
#
#
# Erie-County:
# {'Doctorate': '0.979499%', 'Professional': '1.377371%', "Master's": '6.895376%', "Bachelor's": '17.710347%', "Associate's": '8.366489%', 'Some College': '15.939898%', 'High School': '39.801011%', 'Some H.S.': '6.444775%', 'Less than H.S.': '1.551007%', 'None': '0.934226%'}
#
#
# McKean-County:
# {'Doctorate': '0.660296%', 'Professional': '0.736612%', "Master's": '5.152963%', "Bachelor's": '10.445285%', "Associate's": '7.780875%', 'Some College': '16.895614%', 'High School': '47.889707%', 'Some H.S.': '8.344947%', 'Less than H.S.': '1.177915%', 'None': '0.915787%'}
#
#
# Sullivan-County:
# {'Doctorate': '0.914820%', 'Professional': '0.833503%', "Master's": '4.757064%', "Bachelor's": '9.005896%', "Associate's": '7.948770%', 'Some College': '16.385444%', 'High School': '49.196991%', 'Some H.S.': '7.359219%', 'Less than H.S.': '3.029071%', 'None': '0.569221%'}
#
#
# Lehigh-County:
# {'Doctorate': '1.304435%', 'Professional': '1.603283%', "Master's": '8.232863%', "Bachelor's": '17.767292%', "Associate's": '9.069555%', 'Some College': '16.757196%', 'High School': '33.330737%', 'Some H.S.': '7.567938%', 'Less than H.S.': '3.277486%', 'None': '1.089216%'}
#
#
# Indiana-County:
# {'Doctorate': '2.099920%', 'Professional': '0.844243%', "Master's": '6.014783%', "Bachelor's": '13.194407%', "Associate's": '8.399679%', 'Some College': '14.336094%', 'High School': '44.064476%', 'Some H.S.': '6.606109%', 'Less than H.S.': '3.631668%', 'None': '0.808621%'}
#
#
# Carbon-County:
# {'Doctorate': '0.544896%', 'Professional': '0.710272%', "Master's": '4.772607%', "Bachelor's": '9.948055%', "Associate's": '9.733913%', 'Some College': '16.811195%', 'High School': '46.704124%', 'Some H.S.': '8.249761%', 'Less than H.S.': '1.963320%', 'None': '0.561857%'}
#
#
# Beaver-County:
# {'Doctorate': '0.478356%', 'Professional': '1.147727%', "Master's": '5.669249%', "Bachelor's": '16.108993%', "Associate's": '11.620940%', 'Some College': '17.794666%', 'High School': '39.112512%', 'Some H.S.': '5.633331%', 'Less than H.S.': '1.758324%', 'None': '0.675902%'}
#
#
# Clarion-County:
# {'Doctorate': '1.140932%', 'Professional': '0.972472%', "Master's": '5.938206%', "Bachelor's": '12.822084%', "Associate's": '8.181783%', 'Some College': '13.365749%', 'High School': '46.092883%', 'Some H.S.': '7.737662%', 'Less than H.S.': '3.231364%', 'None': '0.516865%'}
#
#
# Pike-County:
# {'Doctorate': '0.745956%', 'Professional': '1.447598%', "Master's": '7.870701%', "Bachelor's": '15.231788%', "Associate's": '8.129201%', 'Some College': '22.388537%', 'High School': '34.931928%', 'Some H.S.': '6.942564%', 'Less than H.S.': '1.592851%', 'None': '0.718875%'}
#
#
# Mercer-County:
# {'Doctorate': '1.008483%', 'Professional': '1.094817%', "Master's": '5.815670%', "Bachelor's": '13.655814%', "Associate's": '8.182978%', 'Some College': '15.616476%', 'High School': '44.139286%', 'Some H.S.': '7.079402%', 'Less than H.S.': '2.630064%', 'None': '0.777008%'}
#
#
# Bradford-County:
# {'Doctorate': '0.460903%', 'Professional': '0.981426%', "Master's": '4.345334%', "Bachelor's": '11.894061%', "Associate's": '8.690667%', 'Some College': '14.214630%', 'High School': '48.266453%', 'Some H.S.': '8.206833%', 'Less than H.S.': '2.160055%', 'None': '0.779638%'}
#
#
# Lancaster-County:
# {'Doctorate': '0.915922%', 'Professional': '1.395328%', "Master's": '6.683747%', "Bachelor's": '16.655333%', "Associate's": '7.052825%', 'Some College': '14.545552%', 'High School': '37.352178%', 'Some H.S.': '8.454078%', 'Less than H.S.': '5.655804%', 'None': '1.289232%'}
#
#
# Union-County:
# {'Doctorate': '2.518056%', 'Professional': '1.424946%', "Master's": '5.592426%', "Bachelor's": '12.606546%', "Associate's": '7.150758%', 'Some College': '14.926150%', 'High School': '40.949314%', 'Some H.S.': '9.255644%', 'Less than H.S.': '4.235799%', 'None': '1.340360%'}
#
#
# Lawrence-County:
# {'Doctorate': '0.736087%', 'Professional': '1.148550%', "Master's": '5.185926%', "Bachelor's": '13.257504%', "Associate's": '8.821943%', 'Some College': '16.041627%', 'High School': '44.315946%', 'Some H.S.': '7.411638%', 'Less than H.S.': '2.273304%', 'None': '0.807475%'}
#
#
# Centre-County:
# {'Doctorate': '5.733571%', 'Professional': '1.660251%', "Master's": '12.707265%', "Bachelor's": '22.294495%', "Associate's": '7.614549%', 'Some College': '12.146384%', 'High School': '31.143835%', 'Some H.S.': '4.403877%', 'Less than H.S.': '1.619731%', 'None': '0.676043%'}
#
#
# Mifflin-County:
# {'Doctorate': '0.257069%', 'Professional': '0.553923%', "Master's": '2.922634%', "Bachelor's": '8.333333%', "Associate's": '6.512425%', 'Some College': '13.340066%', 'High School': '51.132330%', 'Some H.S.': '10.108336%', 'Less than H.S.': '5.924838%', 'None': '0.915045%'}
#
#
# Lebanon-County:
# {'Doctorate': '0.601882%', 'Professional': '1.409728%', "Master's": '5.686936%', "Bachelor's": '12.160374%', "Associate's": '7.027298%', 'Some College': '15.822893%', 'High School': '43.322733%', 'Some H.S.': '9.111476%', 'Less than H.S.': '3.624101%', 'None': '1.232578%'}
#
#
# Montgomery-County:
# {'Doctorate': '2.678873%', 'Professional': '3.937902%', "Master's": '14.184610%', "Bachelor's": '26.655946%', "Associate's": '6.830671%', 'Some College': '15.053334%', 'High School': '24.561652%', 'Some H.S.': '4.031974%', 'Less than H.S.': '1.501304%', 'None': '0.563734%'}
#
#
# Montour-County:
# {'Doctorate': '1.855732%', 'Professional': '3.689015%', "Master's": '7.273271%', "Bachelor's": '15.676444%', "Associate's": '6.599820%', 'Some College': '13.266986%', 'High School': '41.484585%', 'Some H.S.': '7.138581%', 'Less than H.S.': '2.327148%', 'None': '0.688417%'}
#
#
# Juniata-County:
# {'Doctorate': '0.344887%', 'Professional': '0.212680%', "Master's": '4.437547%', "Bachelor's": '8.317526%', "Associate's": '6.690809%', 'Some College': '10.978904%', 'High School': '51.376674%', 'Some H.S.': '11.208829%', 'Less than H.S.': '5.098580%', 'None': '1.333563%'}
#
#
# Crawford-County:
# {'Doctorate': '1.192899%', 'Professional': '1.032734%', "Master's": '5.926124%', "Bachelor's": '12.481231%', "Associate's": '7.477727%', 'Some College': '15.335847%', 'High School': '44.874704%', 'Some H.S.': '7.437686%', 'Less than H.S.': '3.530315%', 'None': '0.710734%'}
#
#
# Chester-County:
# {'Doctorate': '2.695836%', 'Professional': '3.067365%', "Master's": '14.331581%', "Bachelor's": '30.137968%', "Associate's": '6.144882%', 'Some College': '14.098106%', 'High School': '22.478835%', 'Some H.S.': '3.960370%', 'Less than H.S.': '2.472512%', 'None': '0.612545%'}
#
#
# Wayne-County:
# {'Doctorate': '0.806724%', 'Professional': '0.944204%', "Master's": '6.695027%', "Bachelor's": '12.067132%', "Associate's": '7.229384%', 'Some College': '19.021556%', 'High School': '43.114316%', 'Some H.S.': '7.353895%', 'Less than H.S.': '1.820964%', 'None': '0.946798%'}
#
#
# Philadelphia-County:
# {'Doctorate': '1.401108%', 'Professional': '2.319242%', "Master's": '7.137586%', "Bachelor's": '15.491784%', "Associate's": '5.505036%', 'Some College': '17.246139%', 'High School': '33.508267%', 'Some H.S.': '11.383798%', 'Less than H.S.': '3.923779%', 'None': '2.083261%'}
#
#
# Westmoreland-County:
# {'Doctorate': '1.042764%', 'Professional': '1.325598%', "Master's": '7.396665%', "Bachelor's": '17.140783%', "Associate's": '10.655728%', 'Some College': '16.936260%', 'High School': '38.525989%', 'Some H.S.': '4.944288%', 'Less than H.S.': '1.409232%', 'None': '0.622693%'}
#
#
# Susquehanna-County:
# {'Doctorate': '0.782888%', 'Professional': '0.609277%', "Master's": '4.956106%', "Bachelor's": '10.400288%', "Associate's": '8.579009%', 'Some College': '16.994235%', 'High School': '46.573637%', 'Some H.S.': '8.447982%', 'Less than H.S.': '2.040749%', 'None': '0.615828%'}
#
#
# Greene-County:
# {'Doctorate': '0.769576%', 'Professional': '0.422146%', "Master's": '5.050807%', "Bachelor's": '11.087866%', "Associate's": '6.870143%', 'Some College': '14.816198%', 'High School': '47.706216%', 'Some H.S.': '9.873730%', 'Less than H.S.': '2.615063%', 'None': '0.788255%'}
#
#
# Armstrong-County:
# {'Doctorate': '0.440609%', 'Professional': '0.586131%', "Master's": '3.763365%', "Bachelor's": '10.714069%', "Associate's": '9.244700%', 'Some College': '15.514279%', 'High School': '48.836833%', 'Some H.S.': '7.835964%', 'Less than H.S.': '2.249530%', 'None': '0.814520%'}

# %%
def get_each_Educational_Attainment_Sex_Ratio(results):
    result = []
    i = 0
    for r in results:
        if i < 53 and "%" in r.text.strip():
            i = i + 1
        elif i < 61 and "%" in r.text.strip():
            if i == 52 or i == 55 or i ==58:
                i = i + 1
            else: 
                result.append(r.text.strip())
                i = i + 1
    map = {"Higher Degree (Female)": result[0],"Higher Degree (Male)": result[1],"H.S. Diploma (Female)": result[2],
   "H.S. Diploma (Male)":result[3],"No H.S. Diploma (Female)":result[4],"No H.S. Diploma (Male)":result[5]}
    return(map)

# %%
def get_all_Educational_Attainment_Sex_Ratio(url_list):
    for a_list in url_list:
        county_name = a_list.split("/")[5]
        print(county_name + ":")
        print(get_each_Educational_Attainment_Sex_Ratio(get_soup(a_list)))
        print()

# %%
get_all_Educational_Attainment_Sex_Ratio(get_url_list())
# Out:
# Columbia-County:
# {'Higher Degree (Female)': '29.789%', 'Higher Degree (Male)': '28.055%', 'H.S. Diploma (Female)': '60.378%', 'H.S. Diploma (Male)': '59.638%', 'No H.S. Diploma (Female)': '9.833%', 'No H.S. Diploma (Male)': '12.307%'}
#
# Cumberland-County:
# {'Higher Degree (Female)': '41.329%', 'Higher Degree (Male)': '41.924%', 'H.S. Diploma (Female)': '50.331%', 'H.S. Diploma (Male)': '49.144%', 'No H.S. Diploma (Female)': '8.339%', 'No H.S. Diploma (Male)': '8.932%'}
#
# Bucks-County:
# {'Higher Degree (Female)': '46.377%', 'Higher Degree (Male)': '45.960%', 'H.S. Diploma (Female)': '47.398%', 'H.S. Diploma (Male)': '47.384%', 'No H.S. Diploma (Female)': '6.225%', 'No H.S. Diploma (Male)': '6.657%'}
#
# Delaware-County:
# {'Higher Degree (Female)': '45.102%', 'Higher Degree (Male)': '43.386%', 'H.S. Diploma (Female)': '47.857%', 'H.S. Diploma (Male)': '48.380%', 'No H.S. Diploma (Female)': '7.041%', 'No H.S. Diploma (Male)': '8.234%'}
#
# Elk-County:
# {'Higher Degree (Female)': '30.378%', 'Higher Degree (Male)': '28.121%', 'H.S. Diploma (Female)': '61.514%', 'H.S. Diploma (Male)': '63.067%', 'No H.S. Diploma (Female)': '8.108%', 'No H.S. Diploma (Male)': '8.812%'}
#
# Venango-County:
# {'Higher Degree (Female)': '25.783%', 'Higher Degree (Male)': '23.410%', 'H.S. Diploma (Female)': '63.144%', 'H.S. Diploma (Male)': '65.474%', 'No H.S. Diploma (Female)': '11.073%', 'No H.S. Diploma (Male)': '11.116%'}
#
# Lycoming-County:
# {'Higher Degree (Female)': '31.481%', 'Higher Degree (Male)': '30.449%', 'H.S. Diploma (Female)': '57.934%', 'H.S. Diploma (Male)': '57.801%', 'No H.S. Diploma (Female)': '10.585%', 'No H.S. Diploma (Male)': '11.750%'}
#
# Dauphin-County:
# {'Higher Degree (Female)': '37.845%', 'Higher Degree (Male)': '37.807%', 'H.S. Diploma (Female)': '51.725%', 'H.S. Diploma (Male)': '50.725%', 'No H.S. Diploma (Female)': '10.430%', 'No H.S. Diploma (Male)': '11.468%'}
#
# Forest-County:
# {'Higher Degree (Female)': '22.398%', 'Higher Degree (Male)': '9.303%', 'H.S. Diploma (Female)': '67.655%', 'H.S. Diploma (Male)': '68.656%', 'No H.S. Diploma (Female)': '9.947%', 'No H.S. Diploma (Male)': '22.041%'}
#
# Warren-County:
# {'Higher Degree (Female)': '29.422%', 'Higher Degree (Male)': '26.911%', 'H.S. Diploma (Female)': '63.180%', 'H.S. Diploma (Male)': '62.874%', 'No H.S. Diploma (Female)': '7.397%', 'No H.S. Diploma (Male)': '10.215%'}
#
# Allegheny-County:
# {'Higher Degree (Female)': '47.486%', 'Higher Degree (Male)': '49.747%', 'H.S. Diploma (Female)': '46.285%', 'H.S. Diploma (Male)': '44.229%', 'No H.S. Diploma (Female)': '6.229%', 'No H.S. Diploma (Male)': '6.025%'}
#
# Perry-County:
# {'Higher Degree (Female)': '26.630%', 'Higher Degree (Male)': '23.358%', 'H.S. Diploma (Female)': '62.904%', 'H.S. Diploma (Male)': '63.612%', 'No H.S. Diploma (Female)': '10.466%', 'No H.S. Diploma (Male)': '13.031%'}
#
# Somerset-County:
# {'Higher Degree (Female)': '26.149%', 'Higher Degree (Male)': '21.353%', 'H.S. Diploma (Female)': '61.972%', 'H.S. Diploma (Male)': '64.878%', 'No H.S. Diploma (Female)': '11.879%', 'No H.S. Diploma (Male)': '13.769%'}
#
# Clearfield-County:
# {'Higher Degree (Female)': '24.979%', 'Higher Degree (Male)': '20.387%', 'H.S. Diploma (Female)': '64.050%', 'H.S. Diploma (Male)': '64.953%', 'No H.S. Diploma (Female)': '10.971%', 'No H.S. Diploma (Male)': '14.660%'}
#
# York-County:
# {'Higher Degree (Female)': '32.689%', 'Higher Degree (Male)': '30.115%', 'H.S. Diploma (Female)': '56.427%', 'H.S. Diploma (Male)': '57.805%', 'No H.S. Diploma (Female)': '10.883%', 'No H.S. Diploma (Male)': '12.080%'}
#
# Snyder-County:
# {'Higher Degree (Female)': '25.934%', 'Higher Degree (Male)': '23.827%', 'H.S. Diploma (Female)': '57.258%', 'H.S. Diploma (Male)': '58.745%', 'No H.S. Diploma (Female)': '16.808%', 'No H.S. Diploma (Male)': '17.428%'}
#
# Franklin-County:
# {'Higher Degree (Female)': '30.098%', 'Higher Degree (Male)': '25.745%', 'H.S. Diploma (Female)': '57.648%', 'H.S. Diploma (Male)': '59.507%', 'No H.S. Diploma (Female)': '12.254%', 'No H.S. Diploma (Male)': '14.748%'}
#
# Bedford-County:
# {'Higher Degree (Female)': '22.363%', 'Higher Degree (Male)': '20.249%', 'H.S. Diploma (Female)': '64.630%', 'H.S. Diploma (Male)': '66.059%', 'No H.S. Diploma (Female)': '13.007%', 'No H.S. Diploma (Male)': '13.692%'}
#
# Monroe-County:
# {'Higher Degree (Female)': '33.467%', 'Higher Degree (Male)': '29.373%', 'H.S. Diploma (Female)': '56.892%', 'H.S. Diploma (Male)': '59.322%', 'No H.S. Diploma (Female)': '9.641%', 'No H.S. Diploma (Male)': '11.306%'}
#
# Cameron-County:
# {'Higher Degree (Female)': '23.131%', 'Higher Degree (Male)': '26.988%', 'H.S. Diploma (Female)': '63.055%', 'H.S. Diploma (Male)': '61.198%', 'No H.S. Diploma (Female)': '13.814%', 'No H.S. Diploma (Male)': '11.814%'}
#
# Butler-County:
# {'Higher Degree (Female)': '43.607%', 'Higher Degree (Male)': '42.186%', 'H.S. Diploma (Female)': '50.169%', 'H.S. Diploma (Male)': '51.047%', 'No H.S. Diploma (Female)': '6.224%', 'No H.S. Diploma (Male)': '6.766%'}
#
# Lackawanna-County:
# {'Higher Degree (Female)': '34.401%', 'Higher Degree (Male)': '35.800%', 'H.S. Diploma (Female)': '55.797%', 'H.S. Diploma (Male)': '54.053%', 'No H.S. Diploma (Female)': '9.802%', 'No H.S. Diploma (Male)': '10.147%'}
#
# Potter-County:
# {'Higher Degree (Female)': '23.407%', 'Higher Degree (Male)': '21.770%', 'H.S. Diploma (Female)': '64.986%', 'H.S. Diploma (Male)': '64.817%', 'No H.S. Diploma (Female)': '11.607%', 'No H.S. Diploma (Male)': '13.413%'}
#
# Huntingdon-County:
# {'Higher Degree (Female)': '26.541%', 'Higher Degree (Male)': '17.825%', 'H.S. Diploma (Female)': '64.131%', 'H.S. Diploma (Male)': '68.994%', 'No H.S. Diploma (Female)': '9.328%', 'No H.S. Diploma (Male)': '13.182%'}
#
# Tioga-County:
# {'Higher Degree (Female)': '32.230%', 'Higher Degree (Male)': '24.979%', 'H.S. Diploma (Female)': '58.553%', 'H.S. Diploma (Male)': '62.372%', 'No H.S. Diploma (Female)': '9.217%', 'No H.S. Diploma (Male)': '12.648%'}
#
# Wyoming-County:
# {'Higher Degree (Female)': '29.526%', 'Higher Degree (Male)': '24.632%', 'H.S. Diploma (Female)': '62.950%', 'H.S. Diploma (Male)': '66.163%', 'No H.S. Diploma (Female)': '7.524%', 'No H.S. Diploma (Male)': '9.205%'}
#
# Schuylkill-County:
# {'Higher Degree (Female)': '28.090%', 'Higher Degree (Male)': '21.822%', 'H.S. Diploma (Female)': '60.205%', 'H.S. Diploma (Male)': '65.664%', 'No H.S. Diploma (Female)': '11.705%', 'No H.S. Diploma (Male)': '12.514%'}
#
# Fayette-County:
# {'Higher Degree (Female)': '25.588%', 'Higher Degree (Male)': '21.679%', 'H.S. Diploma (Female)': '62.056%', 'H.S. Diploma (Male)': '65.388%', 'No H.S. Diploma (Female)': '12.355%', 'No H.S. Diploma (Male)': '12.933%'}
#
# Northampton-County:
# {'Higher Degree (Female)': '37.599%', 'Higher Degree (Male)': '36.231%', 'H.S. Diploma (Female)': '53.006%', 'H.S. Diploma (Male)': '53.994%', 'No H.S. Diploma (Female)': '9.396%', 'No H.S. Diploma (Male)': '9.775%'}
#
# Luzerne-County:
# {'Higher Degree (Female)': '32.939%', 'Higher Degree (Male)': '30.131%', 'H.S. Diploma (Female)': '56.286%', 'H.S. Diploma (Male)': '58.824%', 'No H.S. Diploma (Female)': '10.774%', 'No H.S. Diploma (Male)': '11.046%'}
#
# Blair-County:
# {'Higher Degree (Female)': '28.411%', 'Higher Degree (Male)': '27.034%', 'H.S. Diploma (Female)': '62.738%', 'H.S. Diploma (Male)': '63.118%', 'No H.S. Diploma (Female)': '8.850%', 'No H.S. Diploma (Male)': '9.848%'}
#
# Cambria-County:
# {'Higher Degree (Female)': '31.210%', 'Higher Degree (Male)': '28.303%', 'H.S. Diploma (Female)': '59.303%', 'H.S. Diploma (Male)': '62.127%', 'No H.S. Diploma (Female)': '9.487%', 'No H.S. Diploma (Male)': '9.570%'}
#
# Fulton-County:
# {'Higher Degree (Female)': '22.497%', 'Higher Degree (Male)': '17.519%', 'H.S. Diploma (Female)': '64.771%', 'H.S. Diploma (Male)': '69.168%', 'No H.S. Diploma (Female)': '12.732%', 'No H.S. Diploma (Male)': '13.313%'}
#
# Jefferson-County:
# {'Higher Degree (Female)': '25.972%', 'Higher Degree (Male)': '23.170%', 'H.S. Diploma (Female)': '63.792%', 'H.S. Diploma (Male)': '65.196%', 'No H.S. Diploma (Female)': '10.236%', 'No H.S. Diploma (Male)': '11.634%'}
#
# Washington-County:
# {'Higher Degree (Female)': '37.511%', 'Higher Degree (Male)': '37.438%', 'H.S. Diploma (Female)': '54.517%', 'H.S. Diploma (Male)': '54.021%', 'No H.S. Diploma (Female)': '7.973%', 'No H.S. Diploma (Male)': '8.541%'}
#
# Berks-County:
# {'Higher Degree (Female)': '32.837%', 'Higher Degree (Male)': '30.253%', 'H.S. Diploma (Female)': '53.323%', 'H.S. Diploma (Male)': '54.605%', 'No H.S. Diploma (Female)': '13.840%', 'No H.S. Diploma (Male)': '15.142%'}
#
# Adams-County:
# {'Higher Degree (Female)': '31.240%', 'Higher Degree (Male)': '28.724%', 'H.S. Diploma (Female)': '57.559%', 'H.S. Diploma (Male)': '58.002%', 'No H.S. Diploma (Female)': '11.201%', 'No H.S. Diploma (Male)': '13.273%'}
#
# Clinton-County:
# {'Higher Degree (Female)': '28.952%', 'Higher Degree (Male)': '24.971%', 'H.S. Diploma (Female)': '59.160%', 'H.S. Diploma (Male)': '62.163%', 'No H.S. Diploma (Female)': '11.888%', 'No H.S. Diploma (Male)': '12.866%'}
#
# Northumberland-County:
# {'Higher Degree (Female)': '24.419%', 'Higher Degree (Male)': '21.000%', 'H.S. Diploma (Female)': '61.829%', 'H.S. Diploma (Male)': '64.385%', 'No H.S. Diploma (Female)': '13.752%', 'No H.S. Diploma (Male)': '14.615%'}
#
# Erie-County:
# {'Higher Degree (Female)': '36.778%', 'Higher Degree (Male)': '33.787%', 'H.S. Diploma (Female)': '54.838%', 'H.S. Diploma (Male)': '56.702%', 'No H.S. Diploma (Female)': '8.384%', 'No H.S. Diploma (Male)': '9.512%'}
#
# McKean-County:
# {'Higher Degree (Female)': '26.346%', 'Higher Degree (Male)': '23.275%', 'H.S. Diploma (Female)': '63.553%', 'H.S. Diploma (Male)': '65.964%', 'No H.S. Diploma (Female)': '10.101%', 'No H.S. Diploma (Male)': '10.761%'}
#
# Sullivan-County:
# {'Higher Degree (Female)': '25.704%', 'Higher Degree (Male)': '21.294%', 'H.S. Diploma (Female)': '65.770%', 'H.S. Diploma (Male)': '65.402%', 'No H.S. Diploma (Female)': '8.526%', 'No H.S. Diploma (Male)': '13.304%'}
#
# Lehigh-County:
# {'Higher Degree (Female)': '38.079%', 'Higher Degree (Male)': '37.867%', 'H.S. Diploma (Female)': '49.957%', 'H.S. Diploma (Male)': '50.231%', 'No H.S. Diploma (Female)': '11.964%', 'No H.S. Diploma (Male)': '11.902%'}
#
# Indiana-County:
# {'Higher Degree (Female)': '32.120%', 'Higher Degree (Male)': '28.953%', 'H.S. Diploma (Female)': '56.893%', 'H.S. Diploma (Male)': '59.940%', 'No H.S. Diploma (Female)': '10.987%', 'No H.S. Diploma (Male)': '11.108%'}
#
# Carbon-County:
# {'Higher Degree (Female)': '26.533%', 'Higher Degree (Male)': '24.854%', 'H.S. Diploma (Female)': '63.524%', 'H.S. Diploma (Male)': '63.506%', 'No H.S. Diploma (Female)': '9.943%', 'No H.S. Diploma (Male)': '11.640%'}
#
# Beaver-County:
# {'Higher Degree (Female)': '35.643%', 'Higher Degree (Male)': '34.335%', 'H.S. Diploma (Female)': '56.250%', 'H.S. Diploma (Male)': '57.641%', 'No H.S. Diploma (Female)': '8.107%', 'No H.S. Diploma (Male)': '8.023%'}
#
# Clarion-County:
# {'Higher Degree (Female)': '30.273%', 'Higher Degree (Male)': '27.766%', 'H.S. Diploma (Female)': '58.968%', 'H.S. Diploma (Male)': '59.978%', 'No H.S. Diploma (Female)': '10.759%', 'No H.S. Diploma (Male)': '12.256%'}
#
# Pike-County:
# {'Higher Degree (Female)': '36.355%', 'Higher Degree (Male)': '30.386%', 'H.S. Diploma (Female)': '54.811%', 'H.S. Diploma (Male)': '59.924%', 'No H.S. Diploma (Female)': '8.834%', 'No H.S. Diploma (Male)': '9.691%'}
#
# Mercer-County:
# {'Higher Degree (Female)': '30.722%', 'Higher Degree (Male)': '28.717%', 'H.S. Diploma (Female)': '59.398%', 'H.S. Diploma (Male)': '60.142%', 'No H.S. Diploma (Female)': '9.879%', 'No H.S. Diploma (Male)': '11.142%'}
#
# Bradford-County:
# {'Higher Degree (Female)': '28.904%', 'Higher Degree (Male)': '23.725%', 'H.S. Diploma (Female)': '61.316%', 'H.S. Diploma (Male)': '63.699%', 'No H.S. Diploma (Female)': '9.780%', 'No H.S. Diploma (Male)': '12.576%'}
#
# Lancaster-County:
# {'Higher Degree (Female)': '33.334%', 'Higher Degree (Male)': '32.019%', 'H.S. Diploma (Female)': '52.045%', 'H.S. Diploma (Male)': '51.738%', 'No H.S. Diploma (Female)': '14.622%', 'No H.S. Diploma (Male)': '16.243%'}
#
# Union-County:
# {'Higher Degree (Female)': '35.040%', 'Higher Degree (Male)': '24.841%', 'H.S. Diploma (Female)': '52.020%', 'H.S. Diploma (Male)': '58.862%', 'No H.S. Diploma (Female)': '12.940%', 'No H.S. Diploma (Male)': '16.297%'}
#
# Lawrence-County:
# {'Higher Degree (Female)': '29.417%', 'Higher Degree (Male)': '28.853%', 'H.S. Diploma (Female)': '60.726%', 'H.S. Diploma (Male)': '59.948%', 'No H.S. Diploma (Female)': '9.857%', 'No H.S. Diploma (Male)': '11.199%'}
#
# Centre-County:
# {'Higher Degree (Female)': '50.091%', 'Higher Degree (Male)': '49.935%', 'H.S. Diploma (Female)': '43.643%', 'H.S. Diploma (Male)': '42.964%', 'No H.S. Diploma (Female)': '6.266%', 'No H.S. Diploma (Male)': '7.101%'}
#
# Mifflin-County:
# {'Higher Degree (Female)': '19.178%', 'Higher Degree (Male)': '17.933%', 'H.S. Diploma (Female)': '64.379%', 'H.S. Diploma (Male)': '64.574%', 'No H.S. Diploma (Female)': '16.444%', 'No H.S. Diploma (Male)': '17.493%'}
#
# Lebanon-County:
# {'Higher Degree (Female)': '27.936%', 'Higher Degree (Male)': '25.743%', 'H.S. Diploma (Female)': '58.783%', 'H.S. Diploma (Male)': '59.541%', 'No H.S. Diploma (Female)': '13.281%', 'No H.S. Diploma (Male)': '14.717%'}
#
# Montgomery-County:
# {'Higher Degree (Female)': '54.842%', 'Higher Degree (Male)': '53.679%', 'H.S. Diploma (Female)': '39.393%', 'H.S. Diploma (Male)': '39.860%', 'No H.S. Diploma (Female)': '5.766%', 'No H.S. Diploma (Male)': '6.461%'}
#
# Montour-County:
# {'Higher Degree (Female)': '34.119%', 'Higher Degree (Male)': '36.210%', 'H.S. Diploma (Female)': '55.518%', 'H.S. Diploma (Male)': '53.875%', 'No H.S. Diploma (Female)': '10.363%', 'No H.S. Diploma (Male)': '9.915%'}
#
# Juniata-County:
# {'Higher Degree (Female)': '22.035%', 'Higher Degree (Male)': '17.926%', 'H.S. Diploma (Female)': '61.910%', 'H.S. Diploma (Male)': '62.811%', 'No H.S. Diploma (Female)': '16.055%', 'No H.S. Diploma (Male)': '19.263%'}
#
# Crawford-County:
# {'Higher Degree (Female)': '30.722%', 'Higher Degree (Male)': '25.258%', 'H.S. Diploma (Female)': '58.893%', 'H.S. Diploma (Male)': '61.650%', 'No H.S. Diploma (Female)': '10.385%', 'No H.S. Diploma (Male)': '13.092%'}
#
# Chester-County:
# {'Higher Degree (Female)': '56.662%', 'Higher Degree (Male)': '56.074%', 'H.S. Diploma (Female)': '37.058%', 'H.S. Diploma (Male)': '36.064%', 'No H.S. Diploma (Female)': '6.280%', 'No H.S. Diploma (Male)': '7.862%'}
#
# Wayne-County:
# {'Higher Degree (Female)': '31.803%', 'Higher Degree (Male)': '24.140%', 'H.S. Diploma (Female)': '59.860%', 'H.S. Diploma (Male)': '64.155%', 'No H.S. Diploma (Female)': '8.337%', 'No H.S. Diploma (Male)': '11.705%'}
#
# Philadelphia-County:
# {'Higher Degree (Female)': '32.912%', 'Higher Degree (Male)': '30.606%', 'H.S. Diploma (Female)': '50.388%', 'H.S. Diploma (Male)': '51.188%', 'No H.S. Diploma (Female)': '16.700%', 'No H.S. Diploma (Male)': '18.206%'}
#
# Westmoreland-County:
# {'Higher Degree (Female)': '37.999%', 'Higher Degree (Male)': '37.085%', 'H.S. Diploma (Female)': '55.207%', 'H.S. Diploma (Male)': '55.741%', 'No H.S. Diploma (Female)': '6.794%', 'No H.S. Diploma (Male)': '7.174%'}
#
# Susquehanna-County:
# {'Higher Degree (Female)': '27.880%', 'Higher Degree (Male)': '22.750%', 'H.S. Diploma (Female)': '62.786%', 'H.S. Diploma (Male)': '64.358%', 'No H.S. Diploma (Female)': '9.334%', 'No H.S. Diploma (Male)': '12.893%'}
#
# Greene-County:
# {'Higher Degree (Female)': '27.077%', 'Higher Degree (Male)': '21.528%', 'H.S. Diploma (Female)': '60.669%', 'H.S. Diploma (Male)': '64.245%', 'No H.S. Diploma (Female)': '12.255%', 'No H.S. Diploma (Male)': '14.227%'}
#
# Armstrong-County:
# {'Higher Degree (Female)': '26.402%', 'Higher Degree (Male)': '23.024%', 'H.S. Diploma (Female)': '62.877%', 'H.S. Diploma (Male)': '65.889%', 'No H.S. Diploma (Female)': '10.721%', 'No H.S. Diploma (Male)': '11.087%'}

# %%
def get_each_Detailed_Educational_Attainment_Sex_Ratio(results):
    male_result = []
    female_result = []
    i = 0
    for r in results:
        if i < 62 and "%" in r.text.strip():
            i = i + 1
        elif i%3 == 2 and "%" in r.text.strip():
            female_result.append(r.text.strip())
            i = i + 1
        elif i%3 == 0 and "%" in r.text.strip():
            male_result.append(r.text.strip())
            i = i + 1
        elif "%" in r.text.strip():
            i = i + 1
    map = {"Female":{"Doctorate": female_result[0],"Professional": female_result[1],
    "Master's": female_result[2],"Bachelor's":female_result[3],"Associate's":female_result[4],
    "Some College":female_result[5],"High School": female_result[6],"Some H.S.":female_result[7],
    "Less than H.S.":female_result[8], "None":female_result[9]},
    "Male":{"Doctorate": male_result[0],"Professional": male_result[1],
    "Master's": male_result[2],"Bachelor's":male_result[3],"Associate's":male_result[4],
    "Some College":male_result[5],"High School": male_result[6],"Some H.S.":male_result[7],
    "Less than H.S.":male_result[8], "None":male_result[9]}}
    return(map)

# %%
def get_all_Detailed_Educational_Attainment_Sex_Ratio(url_list):
    for a_list in url_list:
        county_name = a_list.split("/")[5]
        print(county_name + ":")
        print(get_each_Detailed_Educational_Attainment_Sex_Ratio(get_soup(a_list)))
        print("\n")

# %%
get_all_Detailed_Educational_Attainment_Sex_Ratio(get_url_list())
# Out:
# Columbia-County:
# {'Female': {'Doctorate': '1.034%', 'Professional': '0.570%', "Master's": '6.191%', "Bachelor's": '14.146%', "Associate's": '7.848%', 'Some College': '15.043%', 'High School': '45.336%', 'Some H.S.': '6.920%', 'Less than H.S.': '2.240%', 'None': '0.672%'}, 'Male': {'Doctorate': '1.460%', 'Professional': '1.612%', "Master's": '4.992%', "Bachelor's": '12.672%', "Associate's": '7.320%', 'Some College': '15.796%', 'High School': '43.842%', 'Some H.S.': '9.505%', 'Less than H.S.': '2.271%', 'None': '0.531%'}}
#
#
# Cumberland-County:
# {'Female': {'Doctorate': '0.880%', 'Professional': '1.566%', "Master's": '9.687%', "Bachelor's": '20.462%', "Associate's": '8.735%', 'Some College': '16.037%', 'High School': '34.294%', 'Some H.S.': '5.640%', 'Less than H.S.': '1.900%', 'None': '0.799%'}, 'Male': {'Doctorate': '1.772%', 'Professional': '2.548%', "Master's": '9.283%', "Bachelor's": '21.140%', "Associate's": '7.182%', 'Some College': '15.675%', 'High School': '33.469%', 'Some H.S.': '6.497%', 'Less than H.S.': '1.779%', 'None': '0.655%'}}
#
#
# Bucks-County:
# {'Female': {'Doctorate': '1.243%', 'Professional': '1.674%', "Master's": '12.070%', "Bachelor's": '22.433%', "Associate's": '8.957%', 'Some College': '17.129%', 'High School': '30.269%', 'Some H.S.': '4.433%', 'Less than H.S.': '1.127%', 'None': '0.665%'}, 'Male': {'Doctorate': '2.175%', 'Professional': '2.747%', "Master's": '10.419%', "Bachelor's": '24.013%', "Associate's": '6.606%', 'Some College': '17.313%', 'High School': '30.071%', 'Some H.S.': '4.781%', 'Less than H.S.': '1.354%', 'None': '0.521%'}}
#
#
# Delaware-County:
# {'Female': {'Doctorate': '1.593%', 'Professional': '2.044%', "Master's": '11.717%', "Bachelor's": '21.172%', "Associate's": '8.576%', 'Some College': '16.145%', 'High School': '31.712%', 'Some H.S.': '4.691%', 'Less than H.S.': '1.503%', 'None': '0.847%'}, 'Male': {'Doctorate': '2.582%', 'Professional': '3.555%', "Master's": '9.499%', "Bachelor's": '21.442%', "Associate's": '6.307%', 'Some College': '16.954%', 'High School': '31.426%', 'Some H.S.': '5.702%', 'Less than H.S.': '1.545%', 'None': '0.986%'}}
#
#
# Elk-County:
# {'Female': {'Doctorate': '0.296%', 'Professional': '0.800%', "Master's": '5.420%', "Bachelor's": '12.188%', "Associate's": '11.675%', 'Some College': '14.406%', 'High School': '47.107%', 'Some H.S.': '6.107%', 'Less than H.S.': '1.261%', 'None': '0.739%'}, 'Male': {'Doctorate': '0.435%', 'Professional': '0.737%', "Master's": '3.443%', "Bachelor's": '12.210%', "Associate's": '11.296%', 'Some College': '12.574%', 'High School': '50.493%', 'Some H.S.': '5.990%', 'Less than H.S.': '1.739%', 'None': '1.083%'}}
#
#
# Venango-County:
# {'Female': {'Doctorate': '0.160%', 'Professional': '0.385%', "Master's": '5.652%', "Bachelor's": '11.128%', "Associate's": '8.458%', 'Some College': '15.580%', 'High School': '47.564%', 'Some H.S.': '7.742%', 'Less than H.S.': '1.801%', 'None': '1.530%'}, 'Male': {'Doctorate': '0.360%', 'Professional': '1.091%', "Master's": '3.562%', "Bachelor's": '10.622%', "Associate's": '7.775%', 'Some College': '14.378%', 'High School': '51.096%', 'Some H.S.': '7.506%', 'Less than H.S.': '2.466%', 'None': '1.144%'}}
#
#
# Lycoming-County:
# {'Female': {'Doctorate': '0.562%', 'Professional': '0.900%', "Master's": '6.064%', "Bachelor's": '12.878%', "Associate's": '11.077%', 'Some College': '17.316%', 'High School': '40.618%', 'Some H.S.': '8.126%', 'Less than H.S.': '1.728%', 'None': '0.731%'}, 'Male': {'Doctorate': '0.763%', 'Professional': '1.868%', "Master's": '4.737%', "Bachelor's": '13.498%', "Associate's": '9.583%', 'Some College': '18.030%', 'High School': '39.771%', 'Some H.S.': '9.220%', 'Less than H.S.': '1.787%', 'None': '0.742%'}}
#
#
# Dauphin-County:
# {'Female': {'Doctorate': '0.810%', 'Professional': '1.848%', "Master's": '8.005%', "Bachelor's": '18.037%', "Associate's": '9.145%', 'Some College': '17.067%', 'High School': '34.659%', 'Some H.S.': '7.201%', 'Less than H.S.': '2.202%', 'None': '1.027%'}, 'Male': {'Doctorate': '1.746%', 'Professional': '3.299%', "Master's": '6.922%', "Bachelor's": '18.052%', "Associate's": '7.788%', 'Some College': '17.470%', 'High School': '33.255%', 'Some H.S.': '7.777%', 'Less than H.S.': '2.506%', 'None': '1.185%'}}
#
#
# Forest-County:
# {'Female': {'Doctorate': '0.461%', 'Professional': '0.132%', "Master's": '5.270%', "Bachelor's": '8.630%', "Associate's": '7.905%', 'Some College': '13.439%', 'High School': '54.216%', 'Some H.S.': '7.576%', 'Less than H.S.': '1.318%', 'None': '1.054%'}, 'Male': {'Doctorate': '0.482%', 'Professional': '0.000%', "Master's": '1.929%', "Bachelor's": '3.998%', "Associate's": '2.893%', 'Some College': '13.884%', 'High School': '54.772%', 'Some H.S.': '17.581%', 'Less than H.S.': '1.527%', 'None': '2.933%'}}
#
#
# Warren-County:
# {'Female': {'Doctorate': '0.547%', 'Professional': '0.467%', "Master's": '5.296%', "Bachelor's": '12.633%', "Associate's": '10.479%', 'Some College': '17.576%', 'High School': '45.604%', 'Some H.S.': '5.643%', 'Less than H.S.': '1.094%', 'None': '0.660%'}, 'Male': {'Doctorate': '0.540%', 'Professional': '1.313%', "Master's": '4.027%', "Bachelor's": '12.020%', "Associate's": '9.011%', 'Some College': '15.260%', 'High School': '47.614%', 'Some H.S.': '7.097%', 'Less than H.S.': '2.441%', 'None': '0.677%'}}
#
#
# Allegheny-County:
# {'Female': {'Doctorate': '1.761%', 'Professional': '2.171%', "Master's": '11.797%', "Bachelor's": '21.640%', "Associate's": '10.117%', 'Some College': '16.419%', 'High School': '29.866%', 'Some H.S.': '4.324%', 'Less than H.S.': '1.132%', 'None': '0.773%'}, 'Male': {'Doctorate': '2.644%', 'Professional': '3.632%', "Master's": '10.305%', "Bachelor's": '24.389%', "Associate's": '8.777%', 'Some College': '16.360%', 'High School': '27.869%', 'Some H.S.': '4.292%', 'Less than H.S.': '0.963%', 'None': '0.770%'}}
#
#
# Perry-County:
# {'Female': {'Doctorate': '0.284%', 'Professional': '0.568%', "Master's": '5.369%', "Bachelor's": '11.053%', "Associate's": '9.354%', 'Some College': '18.251%', 'High School': '44.652%', 'Some H.S.': '7.909%', 'Less than H.S.': '1.804%', 'None': '0.754%'}, 'Male': {'Doctorate': '0.303%', 'Professional': '0.891%', "Master's": '3.386%', "Bachelor's": '10.814%', "Associate's": '7.965%', 'Some College': '15.766%', 'High School': '47.846%', 'Some H.S.': '9.474%', 'Less than H.S.': '2.861%', 'None': '0.695%'}}
#
#
# Somerset-County:
# {'Female': {'Doctorate': '0.499%', 'Professional': '0.620%', "Master's": '4.912%', "Bachelor's": '10.679%', "Associate's": '9.439%', 'Some College': '15.041%', 'High School': '46.931%', 'Some H.S.': '7.924%', 'Less than H.S.': '3.283%', 'None': '0.671%'}, 'Male': {'Doctorate': '0.478%', 'Professional': '1.246%', "Master's": '2.903%', "Bachelor's": '9.681%', "Associate's": '7.045%', 'Some College': '13.659%', 'High School': '51.219%', 'Some H.S.': '8.383%', 'Less than H.S.': '3.633%', 'None': '1.752%'}}
#
#
# Clearfield-County:
# {'Female': {'Doctorate': '0.424%', 'Professional': '0.344%', "Master's": '3.713%', "Bachelor's": '9.727%', "Associate's": '10.771%', 'Some College': '13.296%', 'High School': '50.754%', 'Some H.S.': '8.138%', 'Less than H.S.': '2.153%', 'None': '0.680%'}, 'Male': {'Doctorate': '0.591%', 'Professional': '0.678%', "Master's": '2.422%', "Bachelor's": '8.613%', "Associate's": '8.083%', 'Some College': '14.183%', 'High School': '50.769%', 'Some H.S.': '10.294%', 'Less than H.S.': '2.548%', 'None': '1.818%'}}
#
#
# York-County:
# {'Female': {'Doctorate': '0.536%', 'Professional': '0.938%', "Master's": '6.632%', "Bachelor's": '15.333%', "Associate's": '9.250%', 'Some College': '16.296%', 'High School': '40.132%', 'Some H.S.': '7.653%', 'Less than H.S.': '2.548%', 'None': '0.682%'}, 'Male': {'Doctorate': '0.819%', 'Professional': '1.722%', "Master's": '5.430%', "Bachelor's": '14.801%', "Associate's": '7.344%', 'Some College': '16.683%', 'High School': '41.121%', 'Some H.S.': '8.412%', 'Less than H.S.': '2.658%', 'None': '1.010%'}}
#
#
# Snyder-County:
# {'Female': {'Doctorate': '0.879%', 'Professional': '1.128%', "Master's": '5.339%', "Bachelor's": '9.506%', "Associate's": '9.082%', 'Some College': '13.395%', 'High School': '43.863%', 'Some H.S.': '9.646%', 'Less than H.S.': '6.013%', 'None': '1.150%'}, 'Male': {'Doctorate': '0.996%', 'Professional': '1.297%', "Master's": '2.424%', "Bachelor's": '11.778%', "Associate's": '7.333%', 'Some College': '11.554%', 'High School': '47.190%', 'Some H.S.': '10.682%', 'Less than H.S.': '5.542%', 'None': '1.204%'}}
#
#
# Franklin-County:
# {'Female': {'Doctorate': '0.604%', 'Professional': '0.758%', "Master's": '6.641%', "Bachelor's": '12.902%', "Associate's": '9.194%', 'Some College': '15.536%', 'High School': '42.113%', 'Some H.S.': '8.355%', 'Less than H.S.': '3.247%', 'None': '0.652%'}, 'Male': {'Doctorate': '0.888%', 'Professional': '1.259%', "Master's": '5.139%', "Bachelor's": '11.856%', "Associate's": '6.603%', 'Some College': '15.282%', 'High School': '44.225%', 'Some H.S.': '10.610%', 'Less than H.S.': '3.312%', 'None': '0.825%'}}
#
#
# Bedford-County:
# {'Female': {'Doctorate': '0.445%', 'Professional': '0.512%', "Master's": '4.553%', "Bachelor's": '8.649%', "Associate's": '8.204%', 'Some College': '16.436%', 'High School': '48.194%', 'Some H.S.': '9.211%', 'Less than H.S.': '2.672%', 'None': '1.124%'}, 'Male': {'Doctorate': '0.617%', 'Professional': '1.546%', "Master's": '3.189%', "Bachelor's": '7.999%', "Associate's": '6.898%', 'Some College': '12.561%', 'High School': '53.498%', 'Some H.S.': '9.978%', 'Less than H.S.': '2.486%', 'None': '1.228%'}}
#
#
# Monroe-County:
# {'Female': {'Doctorate': '0.793%', 'Professional': '0.957%', "Master's": '7.391%', "Bachelor's": '15.643%', "Associate's": '8.683%', 'Some College': '21.937%', 'High School': '34.956%', 'Some H.S.': '6.634%', 'Less than H.S.': '2.257%', 'None': '0.750%'}, 'Male': {'Doctorate': '0.734%', 'Professional': '1.020%', "Master's": '6.103%', "Bachelor's": '14.395%', "Associate's": '7.121%', 'Some College': '21.241%', 'High School': '38.081%', 'Some H.S.': '8.177%', 'Less than H.S.': '1.974%', 'None': '1.154%'}}
#
#
# Cameron-County:
# {'Female': {'Doctorate': '0.488%', 'Professional': '1.463%', "Master's": '2.329%', "Bachelor's": '10.347%', "Associate's": '8.505%', 'Some College': '16.956%', 'High School': '46.100%', 'Some H.S.': '11.701%', 'Less than H.S.': '2.004%', 'None': '0.108%'}, 'Male': {'Doctorate': '0.504%', 'Professional': '0.616%', "Master's": '2.352%', "Bachelor's": '13.102%', "Associate's": '10.414%', 'Some College': '15.566%', 'High School': '45.633%', 'Some H.S.': '8.231%', 'Less than H.S.': '2.744%', 'None': '0.840%'}}
#
#
# Butler-County:
# {'Female': {'Doctorate': '0.801%', 'Professional': '1.036%', "Master's": '10.316%', "Bachelor's": '20.989%', "Associate's": '10.465%', 'Some College': '16.316%', 'High School': '33.854%', 'Some H.S.': '4.515%', 'Less than H.S.': '1.088%', 'None': '0.621%'}, 'Male': {'Doctorate': '1.568%', 'Professional': '1.797%', "Master's": '8.374%', "Bachelor's": '21.708%', "Associate's": '8.740%', 'Some College': '16.524%', 'High School': '34.523%', 'Some H.S.': '4.925%', 'Less than H.S.': '1.307%', 'None': '0.534%'}}
#
#
# Lackawanna-County:
# {'Female': {'Doctorate': '0.779%', 'Professional': '0.822%', "Master's": '8.473%', "Bachelor's": '15.706%', "Associate's": '8.622%', 'Some College': '17.143%', 'High School': '38.654%', 'Some H.S.': '6.581%', 'Less than H.S.': '2.086%', 'None': '1.135%'}, 'Male': {'Doctorate': '1.368%', 'Professional': '2.134%', "Master's": '5.678%', "Bachelor's": '17.276%', "Associate's": '9.343%', 'Some College': '17.595%', 'High School': '36.458%', 'Some H.S.': '7.317%', 'Less than H.S.': '1.832%', 'None': '0.999%'}}
#
#
# Potter-County:
# {'Female': {'Doctorate': '0.048%', 'Professional': '0.915%', "Master's": '5.892%', "Bachelor's": '8.444%', "Associate's": '8.107%', 'Some College': '18.414%', 'High School': '46.572%', 'Some H.S.': '8.476%', 'Less than H.S.': '2.103%', 'None': '1.027%'}, 'Male': {'Doctorate': '0.296%', 'Professional': '0.837%', "Master's": '4.745%', "Bachelor's": '8.915%', "Associate's": '6.978%', 'Some College': '15.630%', 'High School': '49.187%', 'Some H.S.': '9.539%', 'Less than H.S.': '2.758%', 'None': '1.116%'}}
#
#
# Huntingdon-County:
# {'Female': {'Doctorate': '0.396%', 'Professional': '0.461%', "Master's": '4.984%', "Bachelor's": '11.853%', "Associate's": '8.847%', 'Some College': '15.736%', 'High School': '48.395%', 'Some H.S.': '6.612%', 'Less than H.S.': '2.090%', 'None': '0.626%'}, 'Male': {'Doctorate': '1.221%', 'Professional': '0.553%', "Master's": '2.738%', "Bachelor's": '7.620%', "Associate's": '5.692%', 'Some College': '15.440%', 'High School': '53.554%', 'Some H.S.': '9.982%', 'Less than H.S.': '2.008%', 'None': '1.192%'}}
#
#
# Tioga-County:
# {'Female': {'Doctorate': '0.566%', 'Professional': '0.735%', "Master's": '7.727%', "Bachelor's": '13.816%', "Associate's": '9.386%', 'Some College': '16.047%', 'High School': '42.506%', 'Some H.S.': '7.080%', 'Less than H.S.': '1.504%', 'None': '0.634%'}, 'Male': {'Doctorate': '1.090%', 'Professional': '1.283%', "Master's": '4.510%', "Bachelor's": '11.193%', "Associate's": '6.903%', 'Some College': '16.614%', 'High School': '45.759%', 'Some H.S.': '9.138%', 'Less than H.S.': '2.600%', 'None': '0.910%'}}
#
#
# Wyoming-County:
# {'Female': {'Doctorate': '0.391%', 'Professional': '0.631%', "Master's": '6.613%', "Bachelor's": '12.514%', "Associate's": '9.378%', 'Some College': '16.171%', 'High School': '46.779%', 'Some H.S.': '5.771%', 'Less than H.S.': '1.533%', 'None': '0.220%'}, 'Male': {'Doctorate': '0.586%', 'Professional': '1.039%', "Master's": '3.949%', "Bachelor's": '11.437%', "Associate's": '7.621%', 'Some College': '17.176%', 'High School': '48.987%', 'Some H.S.': '6.973%', 'Less than H.S.': '1.831%', 'None': '0.401%'}}
#
#
# Schuylkill-County:
# {'Female': {'Doctorate': '0.261%', 'Professional': '0.546%', "Master's": '5.501%', "Bachelor's": '10.256%', "Associate's": '11.527%', 'Some College': '14.735%', 'High School': '45.469%', 'Some H.S.': '8.881%', 'Less than H.S.': '1.855%', 'None': '0.970%'}, 'Male': {'Doctorate': '0.623%', 'Professional': '1.133%', "Master's": '3.305%', "Bachelor's": '9.032%', "Associate's": '7.729%', 'Some College': '15.817%', 'High School': '49.847%', 'Some H.S.': '9.398%', 'Less than H.S.': '2.127%', 'None': '0.989%'}}
#
#
# Fayette-County:
# {'Female': {'Doctorate': '0.457%', 'Professional': '0.385%', "Master's": '4.325%', "Bachelor's": '10.242%', "Associate's": '10.180%', 'Some College': '13.335%', 'High School': '48.722%', 'Some H.S.': '8.838%', 'Less than H.S.': '2.792%', 'None': '0.726%'}, 'Male': {'Doctorate': '0.494%', 'Professional': '0.900%', "Master's": '2.873%', "Bachelor's": '9.752%', "Associate's": '7.660%', 'Some College': '13.208%', 'High School': '52.180%', 'Some H.S.': '9.308%', 'Less than H.S.': '2.400%', 'None': '1.225%'}}
#
#
# Northampton-County:
# {'Female': {'Doctorate': '0.957%', 'Professional': '1.105%', "Master's": '8.263%', "Bachelor's": '17.329%', "Associate's": '9.945%', 'Some College': '18.091%', 'High School': '34.914%', 'Some H.S.': '6.064%', 'Less than H.S.': '2.500%', 'None': '0.832%'}, 'Male': {'Doctorate': '1.638%', 'Professional': '1.801%', "Master's": '6.380%', "Bachelor's": '18.294%', "Associate's": '8.118%', 'Some College': '18.611%', 'High School': '35.383%', 'Some H.S.': '6.700%', 'Less than H.S.': '2.079%', 'None': '0.996%'}}
#
#
# Luzerne-County:
# {'Female': {'Doctorate': '0.687%', 'Professional': '0.906%', "Master's": '7.291%', "Bachelor's": '13.736%', "Associate's": '10.319%', 'Some College': '17.831%', 'High School': '38.456%', 'Some H.S.': '7.267%', 'Less than H.S.': '2.564%', 'None': '0.943%'}, 'Male': {'Doctorate': '1.041%', 'Professional': '1.705%', "Master's": '5.134%', "Bachelor's": '13.568%', "Associate's": '8.682%', 'Some College': '18.915%', 'High School': '39.909%', 'Some H.S.': '8.030%', 'Less than H.S.': '2.051%', 'None': '0.964%'}}
#
#
# Blair-County:
# {'Female': {'Doctorate': '0.314%', 'Professional': '0.646%', "Master's": '5.539%', "Bachelor's": '12.659%', "Associate's": '9.253%', 'Some College': '15.107%', 'High School': '47.632%', 'Some H.S.': '6.863%', 'Less than H.S.': '1.453%', 'None': '0.534%'}, 'Male': {'Doctorate': '1.013%', 'Professional': '1.466%', "Master's": '3.796%', "Bachelor's": '13.672%', "Associate's": '7.088%', 'Some College': '14.441%', 'High School': '48.677%', 'Some H.S.': '7.391%', 'Less than H.S.': '1.787%', 'None': '0.670%'}}
#
#
# Cambria-County:
# {'Female': {'Doctorate': '0.523%', 'Professional': '0.811%', "Master's": '6.252%', "Bachelor's": '12.460%', "Associate's": '11.163%', 'Some College': '15.096%', 'High School': '44.207%', 'Some H.S.': '6.254%', 'Less than H.S.': '2.191%', 'None': '1.042%'}, 'Male': {'Doctorate': '1.049%', 'Professional': '2.183%', "Master's": '4.409%', "Bachelor's": '12.765%', "Associate's": '7.897%', 'Some College': '15.181%', 'High School': '46.945%', 'Some H.S.': '6.662%', 'Less than H.S.': '2.020%', 'None': '0.889%'}}
#
#
# Fulton-County:
# {'Female': {'Doctorate': '0.172%', 'Professional': '0.325%', "Master's": '5.801%', "Bachelor's": '8.367%', "Associate's": '7.831%', 'Some College': '16.446%', 'High School': '48.325%', 'Some H.S.': '9.516%', 'Less than H.S.': '2.317%', 'None': '0.900%'}, 'Male': {'Doctorate': '0.521%', 'Professional': '0.309%', "Master's": '3.511%', "Bachelor's": '7.737%', "Associate's": '5.441%', 'Some College': '12.695%', 'High School': '56.473%', 'Some H.S.': '9.473%', 'Less than H.S.': '2.817%', 'None': '1.023%'}}
#
#
# Jefferson-County:
# {'Female': {'Doctorate': '0.198%', 'Professional': '0.608%', "Master's": '4.278%', "Bachelor's": '10.311%', "Associate's": '10.577%', 'Some College': '13.820%', 'High School': '49.972%', 'Some H.S.': '6.405%', 'Less than H.S.': '3.174%', 'None': '0.657%'}, 'Male': {'Doctorate': '0.564%', 'Professional': '1.051%', "Master's": '3.296%', "Bachelor's": '9.324%', "Associate's": '8.935%', 'Some College': '12.542%', 'High School': '52.654%', 'Some H.S.': '7.416%', 'Less than H.S.': '3.653%', 'None': '0.564%'}}
#
#
# Washington-County:
# {'Female': {'Doctorate': '0.747%', 'Professional': '0.989%', "Master's": '7.908%', "Bachelor's": '17.739%', "Associate's": '10.128%', 'Some College': '15.180%', 'High School': '39.337%', 'Some H.S.': '5.744%', 'Less than H.S.': '1.545%', 'None': '0.683%'}, 'Male': {'Doctorate': '1.041%', 'Professional': '1.827%', "Master's": '6.688%', "Bachelor's": '19.399%', "Associate's": '8.484%', 'Some College': '15.716%', 'High School': '38.305%', 'Some H.S.': '5.696%', 'Less than H.S.': '1.719%', 'None': '1.126%'}}
#
#
# Berks-County:
# {'Female': {'Doctorate': '0.528%', 'Professional': '0.771%', "Master's": '7.645%', "Bachelor's": '15.256%', "Associate's": '8.637%', 'Some College': '16.419%', 'High School': '36.903%', 'Some H.S.': '8.419%', 'Less than H.S.': '4.238%', 'None': '1.183%'}, 'Male': {'Doctorate': '0.887%', 'Professional': '1.491%', "Master's": '5.361%', "Bachelor's": '15.253%', "Associate's": '7.260%', 'Some College': '15.285%', 'High School': '39.320%', 'Some H.S.': '9.406%', 'Less than H.S.': '4.592%', 'None': '1.144%'}}
#
#
# Adams-County:
# {'Female': {'Doctorate': '0.671%', 'Professional': '0.693%', "Master's": '7.405%', "Bachelor's": '13.635%', "Associate's": '8.835%', 'Some College': '16.367%', 'High School': '41.192%', 'Some H.S.': '7.229%', 'Less than H.S.': '3.103%', 'None': '0.869%'}, 'Male': {'Doctorate': '1.383%', 'Professional': '1.526%', "Master's": '6.522%', "Bachelor's": '11.867%', "Associate's": '7.427%', 'Some College': '15.425%', 'High School': '42.577%', 'Some H.S.': '8.606%', 'Less than H.S.': '3.648%', 'None': '1.019%'}}
#
#
# Clinton-County:
# {'Female': {'Doctorate': '0.843%', 'Professional': '0.671%', "Master's": '5.581%', "Bachelor's": '11.209%', "Associate's": '10.647%', 'Some College': '14.027%', 'High School': '45.133%', 'Some H.S.': '9.164%', 'Less than H.S.': '2.131%', 'None': '0.593%'}, 'Male': {'Doctorate': '0.654%', 'Professional': '0.777%', "Master's": '4.022%', "Bachelor's": '11.190%', "Associate's": '8.329%', 'Some College': '15.236%', 'High School': '46.927%', 'Some H.S.': '8.476%', 'Less than H.S.': '3.147%', 'None': '1.242%'}}
#
#
# Northumberland-County:
# {'Female': {'Doctorate': '0.366%', 'Professional': '0.591%', "Master's": '5.237%', "Bachelor's": '9.850%', "Associate's": '8.375%', 'Some College': '13.175%', 'High School': '48.653%', 'Some H.S.': '9.631%', 'Less than H.S.': '3.217%', 'None': '0.905%'}, 'Male': {'Doctorate': '0.512%', 'Professional': '1.057%', "Master's": '3.167%', "Bachelor's": '9.251%', "Associate's": '7.013%', 'Some College': '12.578%', 'High School': '51.807%', 'Some H.S.': '10.328%', 'Less than H.S.': '3.324%', 'None': '0.962%'}}
#
#
# Erie-County:
# {'Female': {'Doctorate': '0.881%', 'Professional': '0.854%', "Master's": '8.456%', "Bachelor's": '17.319%', "Associate's": '9.268%', 'Some College': '15.648%', 'High School': '39.190%', 'Some H.S.': '5.874%', 'Less than H.S.': '1.599%', 'None': '0.910%'}, 'Male': {'Doctorate': '1.084%', 'Professional': '1.934%', "Master's": '5.235%', "Bachelor's": '18.127%', "Associate's": '7.407%', 'Some College': '16.250%', 'High School': '40.452%', 'Some H.S.': '7.052%', 'Less than H.S.': '1.500%', 'None': '0.960%'}}
#
#
# McKean-County:
# {'Female': {'Doctorate': '0.563%', 'Professional': '0.333%', "Master's": '6.666%', "Bachelor's": '10.325%', "Associate's": '8.458%', 'Some College': '17.534%', 'High School': '46.019%', 'Some H.S.': '8.275%', 'Less than H.S.': '0.957%', 'None': '0.869%'}, 'Male': {'Doctorate': '0.753%', 'Professional': '1.123%', "Master's": '3.706%', "Bachelor's": '10.560%', "Associate's": '7.133%', 'Some College': '16.285%', 'High School': '49.679%', 'Some H.S.': '8.412%', 'Less than H.S.': '1.389%', 'None': '0.961%'}}
#
#
# Sullivan-County:
# {'Female': {'Doctorate': '0.828%', 'Professional': '0.455%', "Master's": '5.588%', "Bachelor's": '10.803%', "Associate's": '8.030%', 'Some College': '17.674%', 'High School': '48.096%', 'Some H.S.': '6.250%', 'Less than H.S.': '1.863%', 'None': '0.414%'}, 'Male': {'Doctorate': '0.999%', 'Professional': '1.199%', "Master's": '3.955%', "Bachelor's": '7.271%', "Associate's": '7.871%', 'Some College': '15.142%', 'High School': '50.260%', 'Some H.S.': '8.430%', 'Less than H.S.': '4.155%', 'None': '0.719%'}}
#
#
# Lehigh-County:
# {'Female': {'Doctorate': '0.929%', 'Professional': '1.221%', "Master's": '8.810%', "Bachelor's": '17.352%', "Associate's": '9.767%', 'Some College': '17.116%', 'High School': '32.841%', 'Some H.S.': '7.473%', 'Less than H.S.': '3.418%', 'None': '1.074%'}, 'Male': {'Doctorate': '1.716%', 'Professional': '2.022%', "Master's": '7.600%', "Bachelor's": '18.223%', "Associate's": '8.305%', 'Some College': '16.363%', 'High School': '33.868%', 'Some H.S.': '7.672%', 'Less than H.S.': '3.124%', 'None': '1.106%'}}
#
#
# Indiana-County:
# {'Female': {'Doctorate': '1.840%', 'Professional': '0.684%', "Master's": '6.385%', "Bachelor's": '14.833%', "Associate's": '8.377%', 'Some College': '14.223%', 'High School': '42.670%', 'Some H.S.': '6.343%', 'Less than H.S.': '3.840%', 'None': '0.804%'}, 'Male': {'Doctorate': '2.365%', 'Professional': '1.008%', "Master's": '5.637%', "Bachelor's": '11.521%', "Associate's": '8.422%', 'Some College': '14.451%', 'High School': '45.488%', 'Some H.S.': '6.875%', 'Less than H.S.': '3.419%', 'None': '0.813%'}}
#
#
# Carbon-County:
# {'Female': {'Doctorate': '0.537%', 'Professional': '0.503%', "Master's": '5.396%', "Bachelor's": '9.639%', "Associate's": '10.458%', 'Some College': '18.209%', 'High School': '45.316%', 'Some H.S.': '7.305%', 'Less than H.S.': '2.055%', 'None': '0.582%'}, 'Male': {'Doctorate': '0.553%', 'Professional': '0.925%', "Master's": '4.125%', "Bachelor's": '10.269%', "Associate's": '8.981%', 'Some College': '15.359%', 'High School': '48.147%', 'Some H.S.': '9.232%', 'Less than H.S.': '1.868%', 'None': '0.540%'}}
#
#
# Beaver-County:
# {'Female': {'Doctorate': '0.320%', 'Professional': '0.907%', "Master's": '6.253%', "Bachelor's": '15.715%', "Associate's": '12.448%', 'Some College': '17.180%', 'High School': '39.069%', 'Some H.S.': '5.791%', 'Less than H.S.': '1.712%', 'None': '0.605%'}, 'Male': {'Doctorate': '0.655%', 'Professional': '1.417%', "Master's": '5.017%', "Bachelor's": '16.549%', "Associate's": '10.698%', 'Some College': '18.481%', 'High School': '39.161%', 'Some H.S.': '5.458%', 'Less than H.S.': '1.811%', 'None': '0.755%'}}
#
#
# Clarion-County:
# {'Female': {'Doctorate': '1.013%', 'Professional': '0.551%', "Master's": '6.731%', "Bachelor's": '13.975%', "Associate's": '8.004%', 'Some College': '14.236%', 'High School': '44.732%', 'Some H.S.': '7.088%', 'Less than H.S.': '2.978%', 'None': '0.692%'}, 'Male': {'Doctorate': '1.277%', 'Professional': '1.419%', "Master's": '5.099%', "Bachelor's": '11.602%', "Associate's": '8.370%', 'Some College': '12.445%', 'High School': '47.533%', 'Some H.S.': '8.425%', 'Less than H.S.': '3.499%', 'None': '0.331%'}}
#
#
# Pike-County:
# {'Female': {'Doctorate': '0.411%', 'Professional': '1.199%', "Master's": '9.337%', "Bachelor's": '16.319%', "Associate's": '9.090%', 'Some College': '21.265%', 'High School': '33.546%', 'Some H.S.': '6.653%', 'Less than H.S.': '1.494%', 'None': '0.687%'}, 'Male': {'Doctorate': '1.093%', 'Professional': '1.705%', "Master's": '6.350%', "Bachelor's": '14.104%', "Associate's": '7.132%', 'Some College': '23.554%', 'High School': '36.370%', 'Some H.S.': '7.243%', 'Less than H.S.': '1.695%', 'None': '0.752%'}}
#
#
# Mercer-County:
# {'Female': {'Doctorate': '0.796%', 'Professional': '0.547%', "Master's": '6.861%', "Bachelor's": '13.495%', "Associate's": '9.023%', 'Some College': '15.723%', 'High School': '43.675%', 'Some H.S.': '6.627%', 'Less than H.S.': '2.599%', 'None': '0.653%'}, 'Male': {'Doctorate': '1.238%', 'Professional': '1.686%', "Master's": '4.688%', "Bachelor's": '13.829%', "Associate's": '7.276%', 'Some College': '15.502%', 'High School': '44.640%', 'Some H.S.': '7.567%', 'Less than H.S.': '2.664%', 'None': '0.910%'}}
#
#
# Bradford-County:
# {'Female': {'Doctorate': '0.247%', 'Professional': '0.713%', "Master's": '5.150%', "Bachelor's": '13.418%', "Associate's": '9.376%', 'Some College': '14.831%', 'High School': '46.485%', 'Some H.S.': '7.021%', 'Less than H.S.': '2.041%', 'None': '0.718%'}, 'Male': {'Doctorate': '0.685%', 'Professional': '1.262%', "Master's": '3.504%', "Bachelor's": '10.301%', "Associate's": '7.974%', 'Some College': '13.570%', 'High School': '50.129%', 'Some H.S.': '9.447%', 'Less than H.S.': '2.284%', 'None': '0.844%'}}
#
#
# Lancaster-County:
# {'Female': {'Doctorate': '0.682%', 'Professional': '1.143%', "Master's": '7.064%', "Bachelor's": '16.631%', "Associate's": '7.813%', 'Some College': '14.836%', 'High School': '37.209%', 'Some H.S.': '7.941%', 'Less than H.S.': '5.461%', 'None': '1.220%'}, 'Male': {'Doctorate': '1.170%', 'Professional': '1.669%', "Master's": '6.271%', "Bachelor's": '16.681%', "Associate's": '6.228%', 'Some College': '14.231%', 'High School': '37.508%', 'Some H.S.': '9.011%', 'Less than H.S.': '5.868%', 'None': '1.365%'}}
#
#
# Union-County:
# {'Female': {'Doctorate': '2.065%', 'Professional': '1.163%', "Master's": '7.111%', "Bachelor's": '15.265%', "Associate's": '9.436%', 'Some College': '11.971%', 'High School': '40.049%', 'Some H.S.': '7.931%', 'Less than H.S.': '4.323%', 'None': '0.686%'}, 'Male': {'Doctorate': '2.869%', 'Professional': '1.628%', "Master's": '4.416%', "Bachelor's": '10.547%', "Associate's": '5.380%', 'Some College': '17.215%', 'High School': '41.646%', 'Some H.S.': '10.282%', 'Less than H.S.': '4.168%', 'None': '1.847%'}}
#
#
# Lawrence-County:
# {'Female': {'Doctorate': '0.560%', 'Professional': '0.708%', "Master's": '6.416%', "Bachelor's": '12.545%', "Associate's": '9.188%', 'Some College': '14.802%', 'High School': '45.924%', 'Some H.S.': '6.828%', 'Less than H.S.': '2.296%', 'None': '0.732%'}, 'Male': {'Doctorate': '0.931%', 'Professional': '1.638%', "Master's": '3.819%', "Bachelor's": '14.050%', "Associate's": '8.415%', 'Some College': '17.420%', 'High School': '42.528%', 'Some H.S.': '8.060%', 'Less than H.S.': '2.248%', 'None': '0.891%'}}
#
#
# Centre-County:
# {'Female': {'Doctorate': '3.801%', 'Professional': '1.196%', "Master's": '13.579%', "Bachelor's": '23.054%', "Associate's": '8.461%', 'Some College': '12.983%', 'High School': '30.660%', 'Some H.S.': '4.198%', 'Less than H.S.': '1.511%', 'None': '0.557%'}, 'Male': {'Doctorate': '7.522%', 'Professional': '2.090%', "Master's": '11.900%', "Bachelor's": '21.592%', "Associate's": '6.832%', 'Some College': '11.373%', 'High School': '31.591%', 'Some H.S.': '4.594%', 'Less than H.S.': '1.720%', 'None': '0.786%'}}
#
#
# Mifflin-County:
# {'Female': {'Doctorate': '0.189%', 'Professional': '0.336%', "Master's": '3.123%', "Bachelor's": '8.213%', "Associate's": '7.318%', 'Some College': '13.357%', 'High School': '51.022%', 'Some H.S.': '9.928%', 'Less than H.S.': '5.756%', 'None': '0.760%'}, 'Male': {'Doctorate': '0.331%', 'Professional': '0.790%', "Master's": '2.706%', "Bachelor's": '8.463%', "Associate's": '5.642%', 'Some College': '13.322%', 'High School': '51.251%', 'Some H.S.': '10.304%', 'Less than H.S.': '6.107%', 'None': '1.083%'}}
#
#
# Lebanon-County:
# {'Female': {'Doctorate': '0.354%', 'Professional': '0.986%', "Master's": '6.458%', "Bachelor's": '12.111%', "Associate's": '8.026%', 'Some College': '15.759%', 'High School': '43.024%', 'Some H.S.': '8.867%', 'Less than H.S.': '3.303%', 'None': '1.111%'}, 'Male': {'Doctorate': '0.872%', 'Professional': '1.871%', "Master's": '4.846%', "Bachelor's": '12.215%', "Associate's": '5.939%', 'Some College': '15.892%', 'High School': '43.649%', 'Some H.S.': '9.378%', 'Less than H.S.': '3.974%', 'None': '1.365%'}}
#
#
# Montgomery-County:
# {'Female': {'Doctorate': '2.145%', 'Professional': '2.815%', "Master's": '15.765%', "Bachelor's": '26.253%', "Associate's": '7.863%', 'Some College': '14.757%', 'High School': '24.636%', 'Some H.S.': '3.746%', 'Less than H.S.': '1.478%', 'None': '0.542%'}, 'Male': {'Doctorate': '3.266%', 'Professional': '5.173%', "Master's": '12.446%', "Bachelor's": '27.099%', "Associate's": '5.695%', 'Some College': '15.379%', 'High School': '24.480%', 'Some H.S.': '4.347%', 'Less than H.S.': '1.527%', 'None': '0.588%'}}
#
#
# Montour-County:
# {'Female': {'Doctorate': '1.458%', 'Professional': '2.146%', "Master's": '8.049%', "Bachelor's": '15.580%', "Associate's": '6.885%', 'Some College': '13.869%', 'High School': '41.649%', 'Some H.S.': '7.180%', 'Less than H.S.': '2.510%', 'None': '0.673%'}, 'Male': {'Doctorate': '2.310%', 'Professional': '5.455%', "Master's": '6.385%', "Bachelor's": '15.787%', "Associate's": '6.273%', 'Some College': '12.578%', 'High School': '41.296%', 'Some H.S.': '7.091%', 'Less than H.S.': '2.118%', 'None': '0.706%'}}
#
#
# Juniata-County:
# {'Female': {'Doctorate': '0.205%', 'Professional': '0.193%', "Master's": '5.264%', "Bachelor's": '9.107%', "Associate's": '7.265%', 'Some College': '12.757%', 'High School': '49.153%', 'Some H.S.': '9.630%', 'Less than H.S.': '5.185%', 'None': '1.239%'}, 'Male': {'Doctorate': '0.488%', 'Professional': '0.233%', "Master's": '3.592%', "Bachelor's": '7.510%', "Associate's": '6.103%', 'Some College': '9.161%', 'High School': '53.650%', 'Some H.S.': '12.823%', 'Less than H.S.': '5.010%', 'None': '1.430%'}}
#
#
# Crawford-County:
# {'Female': {'Doctorate': '1.464%', 'Professional': '0.681%', "Master's": '6.816%', "Bachelor's": '13.284%', "Associate's": '8.478%', 'Some College': '15.223%', 'High School': '43.670%', 'Some H.S.': '6.477%', 'Less than H.S.': '3.272%', 'None': '0.636%'}, 'Male': {'Doctorate': '0.897%', 'Professional': '1.417%', "Master's": '4.954%', "Bachelor's": '11.605%', "Associate's": '6.385%', 'Some College': '15.459%', 'High School': '46.191%', 'Some H.S.': '8.487%', 'Less than H.S.': '3.812%', 'None': '0.792%'}}
#
#
# Chester-County:
# {'Female': {'Doctorate': '2.119%', 'Professional': '2.292%', "Master's": '15.153%', "Bachelor's": '30.263%', "Associate's": '6.836%', 'Some College': '14.115%', 'High School': '22.943%', 'Some H.S.': '3.588%', 'Less than H.S.': '2.127%', 'None': '0.566%'}, 'Male': {'Doctorate': '3.312%', 'Professional': '3.895%', "Master's": '13.455%', "Bachelor's": '30.005%', "Associate's": '5.407%', 'Some College': '14.080%', 'High School': '21.984%', 'Some H.S.': '4.358%', 'Less than H.S.': '2.841%', 'None': '0.663%'}}
#
#
# Wayne-County:
# {'Female': {'Doctorate': '0.795%', 'Professional': '0.734%', "Master's": '8.067%', "Bachelor's": '13.485%', "Associate's": '8.723%', 'Some College': '19.041%', 'High School': '40.819%', 'Some H.S.': '5.953%', 'Less than H.S.': '1.832%', 'None': '0.552%'}, 'Male': {'Doctorate': '0.818%', 'Professional': '1.131%', "Master's": '5.478%', "Bachelor's": '10.809%', "Associate's": '5.904%', 'Some College': '19.004%', 'High School': '45.151%', 'Some H.S.': '8.596%', 'Less than H.S.': '1.811%', 'None': '1.297%'}}
#
#
# Philadelphia-County:
# {'Female': {'Doctorate': '1.198%', 'Professional': '2.018%', "Master's": '8.097%', "Bachelor's": '15.232%', "Associate's": '6.367%', 'Some College': '17.923%', 'High School': '32.465%', 'Some H.S.': '10.848%', 'Less than H.S.': '3.740%', 'None': '2.113%'}, 'Male': {'Doctorate': '1.641%', 'Professional': '2.675%', "Master's": '6.004%', "Bachelor's": '15.799%', "Associate's": '4.487%', 'Some College': '16.447%', 'High School': '34.741%', 'Some H.S.': '12.017%', 'Less than H.S.': '4.141%', 'None': '2.048%'}}
#
#
# Westmoreland-County:
# {'Female': {'Doctorate': '0.741%', 'Professional': '0.919%', "Master's": '7.839%', "Bachelor's": '17.080%', "Associate's": '11.420%', 'Some College': '17.050%', 'High School': '38.156%', 'Some H.S.': '4.802%', 'Less than H.S.': '1.374%', 'None': '0.618%'}, 'Male': {'Doctorate': '1.372%', 'Professional': '1.769%', "Master's": '6.914%', "Bachelor's": '17.207%', "Associate's": '9.824%', 'Some College': '16.812%', 'High School': '38.929%', 'Some H.S.': '5.099%', 'Less than H.S.': '1.447%', 'None': '0.628%'}}
#
#
# Susquehanna-County:
# {'Female': {'Doctorate': '0.521%', 'Professional': '0.730%', "Master's": '5.782%', "Bachelor's": '11.121%', "Associate's": '9.726%', 'Some College': '17.848%', 'High School': '44.938%', 'Some H.S.': '7.190%', 'Less than H.S.': '1.623%', 'None': '0.521%'}, 'Male': {'Doctorate': '1.047%', 'Professional': '0.487%', "Master's": '4.122%', "Bachelor's": '9.673%', "Associate's": '7.421%', 'Some College': '16.132%', 'High School': '48.225%', 'Some H.S.': '9.719%', 'Less than H.S.': '2.463%', 'None': '0.711%'}}
#
#
# Greene-County:
# {'Female': {'Doctorate': '0.745%', 'Professional': '0.357%', "Master's": '6.554%', "Bachelor's": '11.502%', "Associate's": '7.919%', 'Some College': '16.210%', 'High School': '44.458%', 'Some H.S.': '8.702%', 'Less than H.S.': '2.963%', 'None': '0.589%'}, 'Male': {'Doctorate': '0.793%', 'Professional': '0.483%', "Master's": '3.654%', "Bachelor's": '10.703%', "Associate's": '5.895%', 'Some College': '13.521%', 'High School': '50.724%', 'Some H.S.': '10.962%', 'Less than H.S.': '2.292%', 'None': '0.973%'}}
#
#
# Armstrong-County:
# {'Female': {'Doctorate': '0.265%', 'Professional': '0.404%', "Master's": '4.299%', "Bachelor's": '11.600%', "Associate's": '9.834%', 'Some College': '15.903%', 'High School': '46.973%', 'Some H.S.': '7.617%', 'Less than H.S.': '2.308%', 'None': '0.796%'}, 'Male': {'Doctorate': '0.624%', 'Professional': '0.776%', "Master's": '3.204%', "Bachelor's": '9.790%', "Associate's": '8.630%', 'Some College': '15.109%', 'High School': '50.780%', 'Some H.S.': '8.064%', 'Less than H.S.': '2.188%', 'None': '0.834%'}}

# %%
def get_each_Bachelor_Degree_by_Age(results):
    result = []
    i = 0
    for r in results:
        if i < 91 and "%" in r.text.strip():
            i = i + 1
        elif i < 95 and "%" in r.text.strip():
            result.append(r.text.strip())
            i = i + 1
    map = {"65+":result[0],"45-64":result[1],"35-44":result[2],"25-34":result[3]}
    return(map)

# %%
def get_all_Bachelor_Degree_by_Age(url_list):
    for a_list in url_list:
        county_name = a_list.split("/")[5]
        print(county_name + ":")
        print(get_each_Bachelor_Degree_by_Age(get_soup(a_list)))
        print("\n")

# %%
get_all_Bachelor_Degree_by_Age(get_url_list())
# Out:
# Columbia-County:
# {'65+': '6.829819%', '45-64': '13.125069%', '35-44': '17.200491%', '25-34': '21.452928%'}
#
#
# Cumberland-County:
# {'65+': '13.370527%', '45-64': '20.492872%', '35-44': '25.114217%', '25-34': '27.149077%'}
#
#
# Bucks-County:
# {'65+': '15.053629%', '45-64': '23.388684%', '35-44': '27.481314%', '25-34': '30.345985%'}
#
#
# Delaware-County:
# {'65+': '14.018912%', '45-64': '20.251515%', '35-44': '25.143510%', '25-34': '28.633178%'}
#
#
# Elk-County:
# {'65+': '5.632040%', '45-64': '12.800809%', '35-44': '18.559954%', '25-34': '16.822430%'}
#
#
# Venango-County:
# {'65+': '7.296942%', '45-64': '11.235819%', '35-44': '13.784928%', '25-34': '13.682093%'}
#
#
# Lycoming-County:
# {'65+': '7.990043%', '45-64': '11.213745%', '35-44': '16.000306%', '25-34': '22.257910%'}
#
#
# Dauphin-County:
# {'65+': '11.604647%', '45-64': '17.343946%', '35-44': '20.439754%', '25-34': '24.588124%'}
#
#
# Forest-County:
# {'65+': '9.763682%', '45-64': '6.140815%', '35-44': '2.229055%', '25-34': '1.649971%'}
#
#
# Warren-County:
# {'65+': '8.398763%', '45-64': '11.519278%', '35-44': '13.987758%', '25-34': '20.959233%'}
#
#
# Allegheny-County:
# {'65+': '12.895091%', '45-64': '21.343743%', '35-44': '27.408762%', '25-34': '34.303066%'}
#
#
# Perry-County:
# {'65+': '6.103286%', '45-64': '11.163522%', '35-44': '13.619436%', '25-34': '14.171851%'}
#
#
# Somerset-County:
# {'65+': '6.340150%', '45-64': '11.270483%', '35-44': '10.531391%', '25-34': '13.727769%'}
#
#
# Clearfield-County:
# {'65+': '6.257318%', '45-64': '8.623418%', '35-44': '10.467112%', '25-34': '13.722999%'}
#
#
# York-County:
# {'65+': '8.736515%', '45-64': '14.155555%', '35-44': '18.609451%', '25-34': '21.925063%'}
#
#
# Snyder-County:
# {'65+': '6.869552%', '45-64': '10.483573%', '35-44': '10.888065%', '25-34': '16.372682%'}
#
#
# Franklin-County:
# {'65+': '9.230492%', '45-64': '11.638926%', '35-44': '13.547671%', '25-34': '17.845156%'}
#
#
# Bedford-County:
# {'65+': '6.398884%', '45-64': '7.891685%', '35-44': '10.767090%', '25-34': '10.754678%'}
#
#
# Monroe-County:
# {'65+': '11.283673%', '45-64': '14.283245%', '35-44': '16.314728%', '25-34': '21.313271%'}
#
#
# Cameron-County:
# {'65+': '5.686789%', '45-64': '10.258024%', '35-44': '16.806723%', '25-34': '27.594340%'}
#
#
# Butler-County:
# {'65+': '10.911567%', '45-64': '20.757433%', '35-44': '29.262632%', '25-34': '30.459514%'}
#
#
# Lackawanna-County:
# {'65+': '8.615093%', '45-64': '16.464720%', '35-44': '21.701375%', '25-34': '23.548127%'}
#
#
# Potter-County:
# {'65+': '6.070288%', '45-64': '8.072713%', '35-44': '9.870276%', '25-34': '15.104478%'}
#
#
# Huntingdon-County:
# {'65+': '8.550623%', '45-64': '7.989451%', '35-44': '12.271127%', '25-34': '12.092609%'}
#
#
# Tioga-County:
# {'65+': '7.786686%', '45-64': '11.702485%', '35-44': '15.516856%', '25-34': '20.008496%'}
#
#
# Wyoming-County:
# {'65+': '7.626459%', '45-64': '11.628187%', '35-44': '15.156250%', '25-34': '16.961942%'}
#
#
# Schuylkill-County:
# {'65+': '5.851254%', '45-64': '8.748157%', '35-44': '10.846304%', '25-34': '16.823147%'}
#
#
# Fayette-County:
# {'65+': '6.704642%', '45-64': '8.991812%', '35-44': '13.887685%', '25-34': '14.199077%'}
#
#
# Northampton-County:
# {'65+': '10.927063%', '45-64': '17.073256%', '35-44': '23.014087%', '25-34': '24.510032%'}
#
#
# Luzerne-County:
# {'65+': '7.850706%', '45-64': '14.079482%', '35-44': '16.944924%', '25-34': '18.572999%'}
#
#
# Blair-County:
# {'65+': '6.682843%', '45-64': '12.391858%', '35-44': '18.069273%', '25-34': '20.861504%'}
#
#
# Cambria-County:
# {'65+': '6.752618%', '45-64': '12.822990%', '35-44': '16.556549%', '25-34': '19.204791%'}
#
#
# Fulton-County:
# {'65+': '5.826606%', '45-64': '7.271010%', '35-44': '9.864713%', '25-34': '12.217195%'}
#
#
# Jefferson-County:
# {'65+': '6.900127%', '45-64': '9.254798%', '35-44': '12.597325%', '25-34': '13.629065%'}
#
#
# Washington-County:
# {'65+': '10.578584%', '45-64': '18.890201%', '35-44': '24.323324%', '25-34': '25.284932%'}
#
#
# Berks-County:
# {'65+': '9.592487%', '45-64': '15.338972%', '35-44': '18.642038%', '25-34': '19.223562%'}
#
#
# Adams-County:
# {'65+': '9.974700%', '45-64': '12.571448%', '35-44': '14.409048%', '25-34': '16.472139%'}
#
#
# Clinton-County:
# {'65+': '7.902468%', '45-64': '9.865968%', '35-44': '14.466158%', '25-34': '16.537154%'}
#
#
# Northumberland-County:
# {'65+': '4.938607%', '45-64': '9.629358%', '35-44': '11.916913%', '25-34': '14.624933%'}
#
#
# Erie-County:
# {'65+': '11.094678%', '45-64': '16.426876%', '35-44': '21.388089%', '25-34': '25.284960%'}
#
#
# McKean-County:
# {'65+': '7.239057%', '45-64': '10.533278%', '35-44': '11.355778%', '25-34': '14.318276%'}
#
#
# Sullivan-County:
# {'65+': '6.191038%', '45-64': '9.884837%', '35-44': '8.952703%', '25-34': '14.442413%'}
#
#
# Lehigh-County:
# {'65+': '11.679986%', '45-64': '17.126735%', '35-44': '21.561105%', '25-34': '23.010729%'}
#
#
# Indiana-County:
# {'65+': '8.870752%', '45-64': '12.021508%', '35-44': '15.772655%', '25-34': '20.917574%'}
#
#
# Carbon-County:
# {'65+': '4.774029%', '45-64': '10.338788%', '35-44': '14.099250%', '25-34': '13.598022%'}
#
#
# Beaver-County:
# {'65+': '9.137041%', '45-64': '15.644858%', '35-44': '20.884495%', '25-34': '24.667491%'}
#
#
# Clarion-County:
# {'65+': '6.357463%', '45-64': '10.769949%', '35-44': '19.671741%', '25-34': '21.687310%'}
#
#
# Pike-County:
# {'65+': '10.264872%', '45-64': '14.500531%', '35-44': '18.789958%', '25-34': '25.114536%'}
#
#
# Mercer-County:
# {'65+': '8.730822%', '45-64': '13.531173%', '35-44': '18.467819%', '25-34': '18.475830%'}
#
#
# Bradford-County:
# {'65+': '8.845929%', '45-64': '10.531469%', '35-44': '15.195133%', '25-34': '17.892644%'}
#
#
# Lancaster-County:
# {'65+': '12.662300%', '45-64': '15.274253%', '35-44': '20.256582%', '25-34': '21.417524%'}
#
#
# Union-County:
# {'65+': '10.561829%', '45-64': '12.747535%', '35-44': '12.784560%', '25-34': '14.715603%'}
#
#
# Lawrence-County:
# {'65+': '7.127954%', '45-64': '12.288657%', '35-44': '19.238057%', '25-34': '21.249460%'}
#
#
# Centre-County:
# {'65+': '15.872375%', '45-64': '19.734244%', '35-44': '25.953505%', '25-34': '29.451588%'}
#
#
# Mifflin-County:
# {'65+': '4.201146%', '45-64': '6.932222%', '35-44': '12.748092%', '25-34': '15.051424%'}
#
#
# Lebanon-County:
# {'65+': '7.349702%', '45-64': '12.579605%', '35-44': '16.486637%', '25-34': '14.369764%'}
#
#
# Montgomery-County:
# {'65+': '17.160196%', '45-64': '25.766072%', '35-44': '31.027572%', '25-34': '36.797526%'}
#
#
# Montour-County:
# {'65+': '8.534928%', '45-64': '15.270655%', '35-44': '20.721599%', '25-34': '23.300971%'}
#
#
# Juniata-County:
# {'65+': '4.580619%', '45-64': '8.724638%', '35-44': '8.788515%', '25-34': '13.521436%'}
#
#
# Crawford-County:
# {'65+': '7.628233%', '45-64': '12.360811%', '35-44': '14.782072%', '25-34': '18.745284%'}
#
#
# Chester-County:
# {'65+': '21.167688%', '45-64': '29.762999%', '35-44': '35.782156%', '25-34': '36.381521%'}
#
#
# Wayne-County:
# {'65+': '10.016962%', '45-64': '12.125084%', '35-44': '10.514019%', '25-34': '17.531760%'}
#
#
# Philadelphia-County:
# {'65+': '7.818052%', '45-64': '11.221809%', '35-44': '15.878318%', '25-34': '26.113396%'}
#
#
# Westmoreland-County:
# {'65+': '10.484512%', '45-64': '16.939680%', '35-44': '23.600672%', '25-34': '24.111599%'}
#
#
# Susquehanna-County:
# {'65+': '8.695652%', '45-64': '9.388484%', '35-44': '10.917226%', '25-34': '16.465293%'}
#
#
# Greene-County:
# {'65+': '7.760360%', '45-64': '11.827858%', '35-44': '11.347075%', '25-34': '13.711073%'}
#
#
# Armstrong-County:
# {'65+': '6.066150%', '45-64': '9.770445%', '35-44': '15.306516%', '25-34': '17.387640%'}
